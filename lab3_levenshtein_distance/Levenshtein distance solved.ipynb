# %%
## imports
import matplotlib.pyplot as plt
import requests
from pathlib import Path
import os
import regex
from bs4 import BeautifulSoup
from spacy.tokenizer import Tokenizer
import unicodedata
# %reload_ext restmagic

# %% [markdown]
# ### TASK 1 --- clean all acts from eventual HTML syntax

# %%
acts_directory = Path("ustawy/")
files = acts_directory.glob('*')
os.makedirs("ustawy_cleaned/", exist_ok=True)
acts_cleaned_dir = Path("ustawy_cleaned/")

for file in files: 
    file_name = file.name
    with open(file, 'r', encoding='utf-8') as f:
        cnt = regex.sub("\p{Cf}", "", f.read().lower())
        cnt = cnt.replace("-","")
        #cnt2 = regex.sub("\p{Z}+", " ", cnt)
        act_cleaned = BeautifulSoup(cnt, "lxml").get_text()  ## remove all html code

    cleaned_file_path = acts_cleaned_dir.joinpath(file_name)
    with open(cleaned_file_path, "w", encoding="utf-8") as f:
        f.write(act_cleaned)

# %% [markdown]
# ### TASK 2 -- tokenize acts using SpaCy tokenizer

# %%
from spacy.lang.pl import Polish

files_cleaned = acts_cleaned_dir.glob("*")

tokens = dict()

tokenizer = Polish().tokenizer

for file in files_cleaned:
    file_name = file.stem
    with open(file, "r", encoding="utf-8") as f:
        doc = tokenizer(f.read())
        tokens[file_name] = doc

# %% [markdown]
# ### TASK 3 --- frequency list for each processed file

# %%
freqs = dict()
for file, doc in tokens.items():
    freqs[file] = dict()
    for token in doc:
        try:
            freqs[file][token.text] += 1
        except KeyError:
            freqs[file][token.text] = 1

# %%
# sort each token dict
def print_frequency_sorted(token_dct, reverse=True):
    return sorted(token_dct.items(), reverse=reverse, key= lambda item: item[1])

print_frequency_sorted(freqs["1996_269"])
# Out:
# [('.', 55),
#  (',', 34),
#  ('nr', 17),
#  ('poz', 17),
#  ('z', 12),
#  ('r', 12),
#  ('w', 12),
#  ('\n', 10),
#  ('"', 10),
#  ('o', 9),
#  ('1', 8),
#  ('2', 8),
#  ('oraz', 7),
#  ('art', 7),
#  (')', 7),
#  ('ust', 6),
#  ('\n         ', 6),
#  ('i', 5),
#  (':', 5),
#  ('dnia', 4),
#  ('\n ', 4),
#  ('po', 4),
#  ('prokuratora', 4),
#  ('generalnego', 4),
#  ('dz.u', 3),
#  ('kwietnia', 3),
#  ('się', 3),
#  ('otrzymuje', 3),
#  ('brzmienie', 3),
#  ('\n             ', 3),
#  ('1996', 2),
#  ('ustawa', 2),
#  ('ustawy', 2),
#  ('policji', 2),
#  ('urzędzie', 2),
#  ('ochrony', 2),
#  ('państwa', 2),
#  ('ustawie', 2),
#  ('6', 2),
#  ('1990', 2),
#  ('(', 2),
#  ('30', 2),
#  ('1991', 2),
#  ('94', 2),
#  ('422', 2),
#  ('107', 2),
#  ('461', 2),
#  ('1992', 2),
#  ('54', 2),
#  ('254', 2),
#  ('1994', 2),
#  ('53', 2),
#  ('214', 2),
#  ('1995', 2),
#  ('4', 2),
#  ('17', 2),
#  ('34', 2),
#  ('163', 2),
#  ('104', 2),
#  ('515', 2),
#  ('wprowadza', 2),
#  ('następujące', 2),
#  ('zmiany', 2),
#  ('ciężkiego', 2),
#  ('lub', 2),
#  (';', 2),
#  ('\n      ', 2),
#  ('minister', 2),
#  ('spraw', 2),
#  ('wewnętrznych', 2),
#  ('może', 2),
#  ('zarządzić', 2),
#  ('na', 2),
#  ('czas', 2),
#  ('określony', 2),
#  ('czynności', 2),
#  ('wymienione', 2),
#  ('uzyskaniu', 2),
#  ('pisemnej', 2),
#  ('zgody', 2),
#  ('bieżąco', 2),
#  ('informuje', 2),
#  ('przeprowadzonych', 2),
#  ('czynnościach', 2),
#  ('ich', 2),
#  ('wyniku', 2),
#  ('59', 1),
#  ('269', 1),
#  ('\n                                ', 1),
#  ('\n                       ', 1),
#  ('25', 1),
#  ('\n                                    \n   ', 1),
#  ('zmianie', 1),
#  ('\n                                    \n                                    \n                                ',
#   1),
#  ('179', 1),
#  ('19a', 1),
#  ('pkt', 1),
#  ('\n          ', 1),
#  ('przeciwko', 1),
#  ('życiu', 1),
#  ('spowodowania', 1),
#  ('uszkodzenia', 1),
#  ('ciała', 1),
#  ('rozstroju', 1),
#  ('zdrowia', 1),
#  ('pozbawienia', 1),
#  ('człowieka', 1),
#  ('wolności', 1),
#  ('celu', 1),
#  ('wymuszenia', 1),
#  ('okupu', 1),
#  ('zachowania', 1),
#  ('określonego', 1),
#  ('211', 1),
#  ('kodeksu', 1),
#  ('karnego', 1),
#  ('\n      \n                                ', 1),
#  ('180', 1),
#  ('6a', 1),
#  ('wyrazie', 1),
#  ('określi', 1),
#  ('dodaje', 1),
#  ('wyrazy', 1),
#  ('zakres', 1),
#  ('10a', 1),
#  ('\n \n                                ', 1),
#  ('3', 1),
#  ('wchodzi', 1),
#  ('życie', 1),
#  ('upływie', 1),
#  ('14', 1),
#  ('dni', 1),
#  ('od', 1),
#  ('ogłoszenia', 1)]

# %%
# TASK 4 --- global frequency list 

def reduce_words_freqs(freqs):
    dct = dict()
    for token, count in [items for tokens_dicts in freqs.values() for items in tokens_dicts.items()]:
        try:
            dct[token] += count
        except KeyError:
            dct[token] = count
    return dct
        
    
global_freqs = reduce_words_freqs(freqs)
g_freq_arr = print_frequency_sorted(global_freqs)
for i in range(50):
    print(g_freq_arr[i])
# Out:
# ('.', 431296)
# (',', 341126)
# ('w', 201201)
# ('\n', 181338)
# (')', 100139)
# ('i', 89918)
# ('art', 83799)
# ('z', 82438)
# ('1', 71416)
# ('o', 64766)
# ('do', 60730)
# ('2', 56385)
# ('\n  ', 54976)
# ('"', 54914)
# ('ust', 53636)
# ('\n     ', 53410)
# ('na', 50642)
# ('\n   ', 46689)
# ('się', 45886)
# ('lub', 45800)
# ('poz', 45224)
# ('nr', 44942)
# (':', 39203)
# ('3', 37937)
# ('oraz', 33558)
# ('r', 33061)
# ('\n           ', 32959)
# ('mowa', 28783)
# (';', 25266)
# ('4', 23382)
# ('nie', 22988)
# (' ', 22966)
# ('przez', 20951)
# ('\n       ', 20542)
# ('\n             ', 20485)
# ('§', 20464)
# ('pkt', 19124)
# ('dnia', 17954)
# ('których', 17934)
# ('\n ', 17455)
# ('a', 16923)
# ('5', 16854)
# ('_', 16809)
# ('od', 16682)
# ('\n         ', 16483)
# ('po', 13546)
# ('jest', 13197)
# ('ustawy', 13099)
# ('(', 13035)
# ('6', 12292)

# %%
len(global_freqs)
# Out:
# 66812

# %%
# TASK 5 --- Reject entries shorter than 2 characters or containing non-letter characters 
#pattern = regex.compile(r"\p{Ll}{2,}+$", regex.UNICODE) 
pattern_pol_only = regex.compile(r"[A-Za-zĄąĆćĘęŁłŃńÓóŚśŹźŻż]{2,}+$", regex.UNICODE) 


def filter_out_non_letters(item):
    word = item[0].lower()
    #return regex.match(pattern, word)
    return regex.match(pattern_pol_only, word)


g_freq_arr2_filtered = list(filter(filter_out_non_letters, g_freq_arr))  # jest posortowana
#g_freq_arr2 = list(filter(filter_out_non_letters, g_freq_arr))

# %%
len(g_freq_arr2_filtered)
# Out:
# 55223

# %%
print(g_freq_arr2_filtered[:100])
# Out:
# [('art', 83799), ('do', 60730), ('ust', 53636), ('na', 50642), ('się', 45886), ('lub', 45800), ('poz', 45224), ('nr', 44942), ('oraz', 33558), ('mowa', 28783), ('nie', 22988), ('przez', 20951), ('pkt', 19124), ('dnia', 17954), ('których', 17934), ('od', 16682), ('po', 13546), ('jest', 13197), ('ustawy', 13099), ('może', 12096), ('jeżeli', 12038), ('którym', 11790), ('za', 11139), ('brzmienie', 10576), ('spraw', 10021), ('otrzymuje', 9835), ('albo', 8708), ('dodaje', 8423), ('ich', 8199), ('dla', 7934), ('pracy', 7631), ('minister', 7569), ('której', 7477), ('brzmieniu', 7296), ('drodze', 7179), ('podstawie', 6852), ('stosuje', 6680), ('przypadku', 6503), ('niż', 6452), ('tym', 6366), ('jego', 6320), ('są', 6156), ('być', 6120), ('zakresie', 6101), ('właściwy', 6094), ('państwa', 5838), ('przepisy', 5838), ('wyrazy', 5817), ('ze', 5509), ('ustawie', 5479), ('także', 5445), ('przepisów', 5347), ('rozporządzenia', 5346), ('tych', 5048), ('określonych', 5046), ('postępowania', 4909), ('osób', 4904), ('terminie', 4827), ('zastępuje', 4818), ('działalności', 4742), ('przed', 4697), ('ochrony', 4607), ('osoby', 4599), ('wniosek', 4596), ('innych', 4593), ('że', 4587), ('urzędu', 4551), ('sposób', 4538), ('odpowiednio', 4452), ('prawa', 4424), ('życie', 4400), ('środków', 4225), ('które', 4105), ('czynności', 4044), ('rady', 4042), ('polskiej', 4019), ('zmiany', 4016), ('prawo', 4015), ('tego', 4014), ('roku', 3966), ('mogą', 3927), ('informacji', 3851), ('służby', 3847), ('organ', 3833), ('dni', 3767), ('to', 3704), ('jej', 3703), ('przy', 3694), ('określi', 3595), ('rzeczypospolitej', 3567), ('co', 3493), ('szczególności', 3475), ('dniem', 3466), ('umowy', 3465), ('decyzji', 3386), ('jednostki', 3379), ('celu', 3376), ('wysokości', 3369), ('środowiska', 3335), ('ustawa', 3235)]

# %% [markdown]
# ### TASK 6 --- plot ranks of terms (frequency) in logarithmic scale

# %%
ranks = list(range(len(g_freq_arr2_filtered)))

y_freq = [item[1] for item in reversed(g_freq_arr2_filtered)]

# %%
g_freq_arr2_filtered[:100]

# %%
fig1 = plt.figure(1)
fig1.set_size_inches(20.5, 8.5)
ax1 = fig1.gca()

ax1.set_xscale("log", base=10); 
ax1.set_yscale("log", base=10)

ax1.tick_params(bottom=False, left=False)
#ax1.set_ylim(bottom=10**3)

#ax1.set_xticklabels(ranks)
#ax1.set_yticklabels(y_freq)
#xlbls = ax1.get_xticklabels()
#for lbl in xlbls:
##    lbl.set_rotation("vertical")
  #  lbl.set_fontsize(9)

xs = [items[0] for items in g_freq_arr2_filtered]
ys = [items[1] for items in g_freq_arr2_filtered]


plt.plot(xs, ys)




plt.show()

# %% [markdown]
# ### TASK 7 --- find words not contained in the dictionary

# %%
import morfeusz2
morf = morfeusz2.Morfeusz(generate=False)  # for speed
#analys = morf.analyse("porozumiewać")
analys

# %%
# TASK 7 -- Find words that are not in the dictionary 

import morfeusz2
morf = morfeusz2.Morfeusz()  # for speed

not_known_words = set()

for token,_ in g_freq_arr2_filtered:
    analysis = morf.analyse(token)
    for edge in analysis:
        if edge[2][2] == 'ign' and edge[2][0] == edge[2][1]:
            print(analysis)
            #break
            not_known_words.add(token)
    #if not_known_words:
    #    break
# Out:
# [(0, 1, ('poz', 'poz', 'ign', [], []))]
# [(0, 1, ('późn', 'późn', 'ign', [], []))]
# [(0, 1, ('str', 'str', 'ign', [], []))]
# [(0, 1, ('gmo', 'gmo', 'ign', [], []))]
# [(0, 1, ('sww', 'sww', 'ign', [], []))]
# [(0, 1, ('skw', 'skw', 'ign', [], []))]
# [(0, 1, ('zm', 'zm', 'ign', [], []))]
# [(0, 1, ('ex', 'ex', 'ign', [], []))]
# [(0, 1, ('ike', 'ike', 'ign', [], []))]
# [(0, 1, ('remediacji', 'remediacji', 'ign', [], []))]
# [(0, 1, ('ure', 'ure', 'ign', [], []))]
# [(0, 1, ('rozdz', 'rozdz', 'ign', [], []))]
# [(0, 1, ('uke', 'uke', 'ign', [], []))]
# [(0, 1, ('itp', 'itp', 'ign', [], []))]
# [(0, 1, ('kn', 'kn', 'ign', [], []))]
# [(0, 1, ('np', 'np', 'ign', [], []))]
# [(0, 1, ('cn', 'cn', 'ign', [], []))]
# [(0, 1, ('pkwiu', 'pkwiu', 'ign', [], []))]
# [(0, 1, ('udt', 'udt', 'ign', [], []))]
# [(0, 1, ('bswsg', 'bswsg', 'ign', [], []))]
# [(0, 1, ('bswp', 'bswp', 'ign', [], []))]
# [(0, 1, ('biobójczych', 'biobójczych', 'ign', [], []))]
# [(0, 1, ('phs', 'phs', 'ign', [], []))]
# [(0, 1, ('fep', 'fep', 'ign', [], []))]
# [(0, 1, ('mgo', 'mgo', 'ign', [], []))]
# [(0, 1, ('utk', 'utk', 'ign', [], []))]
# [(0, 1, ('frd', 'frd', 'ign', [], []))]
# [(0, 1, ('uokik', 'uokik', 'ign', [], []))]
# [(0, 1, ('ron', 'ron', 'ign', [], []))]
# [(0, 1, ('cbśp', 'cbśp', 'ign', [], []))]
# [(0, 1, ('doke', 'doke', 'ign', [], []))]
# [(0, 1, ('pcn', 'pcn', 'ign', [], []))]
# [(0, 1, ('vitro', 'vitro', 'ign', [], []))]
# [(0, 1, ('haccp', 'haccp', 'ign', [], []))]
# [(0, 1, ('its', 'its', 'ign', [], []))]
# [(0, 1, ('inulinowego', 'inulinowego', 'ign', [], []))]
# [(0, 1, ('efrrow', 'efrrow', 'ign', [], []))]
# [(0, 1, ('pcb', 'pcb', 'ign', [], []))]
# [(0, 1, ('plk', 'plk', 'ign', [], []))]
# [(0, 1, ('ureaformu', 'ureaformu', 'ign', [], []))]
# [(0, 1, ('biuretu', 'biuretu', 'ign', [], []))]
# [(0, 1, ('ych', 'ych', 'ign', [], []))]
# [(0, 1, ('tdt', 'tdt', 'ign', [], []))]
# [(0, 1, ('cu', 'cu', 'ign', [], []))]
# [(0, 1, ('warszawacentrum', 'warszawacentrum', 'ign', [], []))]
# [(0, 1, ('disease', 'disease', 'ign', [], []))]
# [(0, 1, ('tj', 'tj', 'ign', [], []))]
# [(0, 1, ('prefinansowanie', 'prefinansowanie', 'ign', [], []))]
# [(0, 1, ('iva', 'iva', 'ign', [], []))]
# [(0, 1, ('wymienion', 'wymienion', 'ign', [], []))]
# [(0, 1, ('bankowania', 'bankowania', 'ign', [], []))]
# [(0, 1, ('iia', 'iia', 'ign', [], []))]
# [(0, 1, ('rozpuszc', 'rozpuszc', 'ign', [], []))]
# [(0, 1, ('iiia', 'iiia', 'ign', [], []))]
# [(0, 1, ('zalny', 'zalny', 'ign', [], []))]
# [(0, 1, ('ww', 'ww', 'ign', [], []))]
# [(0, 1, ('ureaform', 'ureaform', 'ign', [], []))]
# [(0, 1, ('ie', 'ie', 'ign', [], []))]
# [(0, 1, ('sędziegokomisarza', 'sędziegokomisarza', 'ign', [], []))]
# [(0, 1, ('zn', 'zn', 'ign', [], []))]
# [(0, 1, ('abw', 'abw', 'ign', [], []))]
# [(0, 1, ('wdt', 'wdt', 'ign', [], []))]
# [(0, 1, ('cao', 'cao', 'ign', [], []))]
# [(0, 1, ('npk', 'npk', 'ign', [], []))]
# [(0, 1, ('marpol', 'marpol', 'ign', [], []))]
# [(0, 1, ('bielskubiałej', 'bielskubiałej', 'ign', [], []))]
# [(0, 1, ('nia', 'nia', 'ign', [], []))]
# [(0, 1, ('iiar', 'iiar', 'ign', [], []))]
# [(0, 1, ('efrg', 'efrg', 'ign', [], []))]
# [(0, 1, ('chelatującego', 'chelatującego', 'ign', [], []))]
# [(0, 1, ('wym', 'wym', 'ign', [], []))]
# [(0, 1, ('wpowinno', 'wpowinno', 'ign', [], []))]
# [(0, 1, ('bovine', 'bovine', 'ign', [], []))]
# [(0, 1, ('solas', 'solas', 'ign', [], []))]
# [(0, 1, ('epuap', 'epuap', 'ign', [], []))]
# [(0, 1, ('ktrych', 'ktrych', 'ign', [], []))]
# [(0, 1, ('nastawów', 'nastawów', 'ign', [], []))]
# [(0, 1, ('propionanilid', 'propionanilid', 'ign', [], []))]
# [(0, 1, ('email', 'email', 'ign', [], []))]
# [(0, 1, ('operacyjno', 'operacyjno', 'ign', [], []))]
# [(0, 1, ('rasff', 'rasff', 'ign', [], []))]
# [(0, 1, ('ny', 'ny', 'ign', [], []))]
# [(0, 1, ('amonow', 'amonow', 'ign', [], []))]
# [(0, 1, ('zawartoś', 'zawartoś', 'ign', [], []))]
# [(0, 1, ('alny', 'alny', 'ign', [], []))]
# [(0, 1, ('rozpuszczaln', 'rozpuszczaln', 'ign', [], []))]
# [(0, 1, ('knowhow', 'knowhow', 'ign', [], []))]
# [(0, 1, ('infectious', 'infectious', 'ign', [], []))]
# [(0, 1, ('nusp', 'nusp', 'ign', [], []))]
# [(0, 1, ('vitis', 'vitis', 'ign', [], []))]
# [(0, 1, ('betaagonistycznym', 'betaagonistycznym', 'ign', [], []))]
# [(0, 1, ('azotanow', 'azotanow', 'ign', [], []))]
# [(0, 1, ('rozpuszczalno', 'rozpuszczalno', 'ign', [], []))]
# [(0, 1, ('rozpuszcz', 'rozpuszcz', 'ign', [], []))]
# [(0, 1, ('wapniowo', 'wapniowo', 'ign', [], []))]
# [(0, 1, ('wymiarz', 'wymiarz', 'ign', [], []))]
# [(0, 1, ('remediacja', 'remediacja', 'ign', [], []))]
# [(0, 1, ('torfiarskie', 'torfiarskie', 'ign', [], []))]
# [(0, 1, ('equine', 'equine', 'ign', [], []))]
# [(0, 1, ('of', 'of', 'ign', [], []))]
# [(0, 1, ('porealizacyjnej', 'porealizacyjnej', 'ign', [], []))]
# [(0, 1, ('techniczno', 'techniczno', 'ign', [], []))]
# [(0, 1, ('kv', 'kv', 'ign', [], []))]
# [(0, 1, ('ycie', 'ycie', 'ign', [], []))]
# [(0, 1, ('iip', 'iip', 'ign', [], []))]
# [(0, 1, ('środkw', 'środkw', 'ign', [], []))]
# [(0, 1, ('kśt', 'kśt', 'ign', [], []))]
# [(0, 1, ('iibr', 'iibr', 'ign', [], []))]
# [(0, 1, ('iin', 'iin', 'ign', [], []))]
# [(0, 1, ('realokacji', 'realokacji', 'ign', [], []))]
# [(0, 1, ('curieskłodowskiej', 'curieskłodowskiej', 'ign', [], []))]
# [(0, 1, ('najwyże', 'najwyże', 'ign', [], []))]
# [(0, 1, ('eures', 'eures', 'ign', [], []))]
# [(0, 1, ('rekapitalizacyjnej', 'rekapitalizacyjnej', 'ign', [], []))]
# [(0, 1, ('msr', 'msr', 'ign', [], []))]
# [(0, 1, ('iiip', 'iiip', 'ign', [], []))]
# [(0, 1, ('tyreostatycznym', 'tyreostatycznym', 'ign', [], []))]
# [(0, 1, ('aetr', 'aetr', 'ign', [], []))]
# [(0, 1, ('ch', 'ch', 'ign', [], []))]
# [(0, 1, ('ią', 'ią', 'ign', [], []))]
# [(0, 1, ('oczapowskiego', 'oczapowskiego', 'ign', [], []))]
# [(0, 1, ('ministraszefa', 'ministraszefa', 'ign', [], []))]
# [(0, 1, ('gt', 'gt', 'ign', [], []))]
# [(0, 1, ('miesiący', 'miesiący', 'ign', [], []))]
# [(0, 1, ('ktrym', 'ktrym', 'ign', [], []))]
# [(0, 1, ('produktw', 'produktw', 'ign', [], []))]
# [(0, 1, ('sdr', 'sdr', 'ign', [], []))]
# [(0, 1, ('marakeszu', 'marakeszu', 'ign', [], []))]
# [(0, 1, ('liqueur', 'liqueur', 'ign', [], []))]
# [(0, 1, ('etc', 'etc', 'ign', [], []))]
# [(0, 1, ('ivp', 'ivp', 'ign', [], []))]
# [(0, 1, ('nawozw', 'nawozw', 'ign', [], []))]
# [(0, 1, ('idenodim', 'idenodim', 'ign', [], []))]
# [(0, 1, ('ści', 'ści', 'ign', [], []))]
# [(0, 1, ('dobrowoln', 'dobrowoln', 'ign', [], []))]
# [(0, 1, ('ministerszef', 'ministerszef', 'ign', [], []))]
# [(0, 1, ('fever', 'fever', 'ign', [], []))]
# [(0, 1, ('avian', 'avian', 'ign', [], []))]
# [(0, 1, ('iiib', 'iiib', 'ign', [], []))]
# [(0, 1, ('moe', 'moe', 'ign', [], []))]
# [(0, 1, ('jeeli', 'jeeli', 'ign', [], []))]
# [(0, 1, ('stcw', 'stcw', 'ign', [], []))]
# [(0, 1, ('vinifera', 'vinifera', 'ign', [], []))]
# [(0, 1, ('milirównoważników', 'milirównoważników', 'ign', [], []))]
# [(0, 1, ('inulinowy', 'inulinowy', 'ign', [], []))]
# [(0, 1, ('modakrylowych', 'modakrylowych', 'ign', [], []))]
# [(0, 1, ('godz', 'godz', 'ign', [], []))]
# [(0, 1, ('db', 'db', 'ign', [], []))]
# [(0, 1, ('domicylowego', 'domicylowego', 'ign', [], []))]
# [(0, 1, ('kokcydiostatyków', 'kokcydiostatyków', 'ign', [], []))]
# [(0, 1, ('ywienia', 'ywienia', 'ign', [], []))]
# [(0, 1, ('ji', 'ji', 'ign', [], []))]
# [(0, 1, ('rozpuszczal', 'rozpuszczal', 'ign', [], []))]
# [(0, 1, ('magnezowyc', 'magnezowyc', 'ign', [], []))]
# [(0, 1, ('obj', 'obj', 'ign', [], []))]
# [(0, 1, ('viral', 'viral', 'ign', [], []))]
# [(0, 1, ('odpo', 'odpo', 'ign', [], []))]
# [(0, 1, ('przepisw', 'przepisw', 'ign', [], []))]
# [(0, 1, ('kogeneracji', 'kogeneracji', 'ign', [], []))]
# [(0, 1, ('gwh', 'gwh', 'ign', [], []))]
# [(0, 1, ('mwh', 'mwh', 'ign', [], []))]
# [(0, 1, ('odp', 'odp', 'ign', [], []))]
# [(0, 1, ('hcfc', 'hcfc', 'ign', [], []))]
# [(0, 1, ('polichlorowane', 'polichlorowane', 'ign', [], []))]
# [(0, 1, ('syloe', 'syloe', 'ign', [], []))]
# [(0, 1, ('kev', 'kev', 'ign', [], []))]
# [(0, 1, ('wo', 'wo', 'ign', [], []))]
# [(0, 1, ('tmb', 'tmb', 'ign', [], []))]
# [(0, 1, ('windcheater', 'windcheater', 'ign', [], []))]
# [(0, 1, ('windjacket', 'windjacket', 'ign', [], []))]
# [(0, 1, ('nfośigw', 'nfośigw', 'ign', [], []))]
# [(0, 1, ('tzw', 'tzw', 'ign', [], []))]
# [(0, 1, ('mwt', 'mwt', 'ign', [], []))]
# [(0, 1, ('ktrej', 'ktrej', 'ign', [], []))]
# [(0, 1, ('mlc', 'mlc', 'ign', [], []))]
# [(0, 1, ('aktw', 'aktw', 'ign', [], []))]
# [(0, 1, ('iib', 'iib', 'ign', [], []))]
# [(0, 1, ('krotonyl', 'krotonyl', 'ign', [], []))]
# [(0, 1, ('zawartośc', 'zawartośc', 'ign', [], []))]
# [(0, 1, ('otrzymy', 'otrzymy', 'ign', [], []))]
# [(0, 1, ('otrzymywan', 'otrzymywan', 'ign', [], []))]
# [(0, 1, ('zaw', 'zaw', 'ign', [], []))]
# [(0, 1, ('joulie', 'joulie', 'ign', [], []))]
# [(0, 1, ('ące', 'ące', 'ign', [], []))]
# [(0, 1, ('rozpus', 'rozpus', 'ign', [], []))]
# [(0, 1, ('zczaln', 'zczaln', 'ign', [], []))]
# [(0, 1, ('ść', 'ść', 'ign', [], []))]
# [(0, 1, ('remediację', 'remediację', 'ign', [], []))]
# [(0, 1, ('regazyfikacyjnego', 'regazyfikacyjnego', 'ign', [], []))]
# [(0, 1, ('denitracyjne', 'denitracyjne', 'ign', [], []))]
# [(0, 1, ('odgazowywacze', 'odgazowywacze', 'ign', [], []))]
# [(0, 1, ('swine', 'swine', 'ign', [], []))]
# [(0, 1, ('contagious', 'contagious', 'ign', [], []))]
# [(0, 1, ('jed', 'jed', 'ign', [], []))]
# [(0, 1, ('sędziakomisarz', 'sędziakomisarz', 'ign', [], []))]
# [(0, 1, ('próbobiorców', 'próbobiorców', 'ign', [], []))]
# [(0, 1, ('eudravigilance', 'eudravigilance', 'ign', [], []))]
# [(0, 1, ('vista', 'vista', 'ign', [], []))]
# [(0, 1, ('instrumen', 'instrumen', 'ign', [], []))]
# [(0, 1, ('tzn', 'tzn', 'ign', [], []))]
# [(0, 1, ('wlkp', 'wlkp', 'ign', [], []))]
# [(0, 1, ('winopochodne', 'winopochodne', 'ign', [], []))]
# [(0, 1, ('rci', 'rci', 'ign', [], []))]
# [(0, 1, ('xxxixxliv', 'xxxixxliv', 'ign', [], []))]
# [(0, 1, ('urt', 'urt', 'ign', [], []))]
# [(0, 1, ('rr', 'rr', 'ign', [], []))]
# [(0, 1, ('betezda', 'betezda', 'ign', [], []))]
# [(0, 1, ('inci', 'inci', 'ign', [], []))]
# [(0, 1, ('agave', 'agave', 'ign', [], []))]
# [(0, 1, ('schetyna', 'schetyna', 'ign', [], []))]
# [(0, 1, ('państwamistronami', 'państwamistronami', 'ign', [], []))]
# [(0, 1, ('iiin', 'iiin', 'ign', [], []))]
# [(0, 1, ('shigella', 'shigella', 'ign', [], []))]
# [(0, 1, ('gj', 'gj', 'ign', [], []))]
# [(0, 1, ('cz', 'cz', 'ign', [], []))]
# [(0, 1, ('ivn', 'ivn', 'ign', [], []))]
# [(0, 1, ('sposb', 'sposb', 'ign', [], []))]
# [(0, 1, ('ppkt', 'ppkt', 'ign', [], []))]
# [(0, 1, ('tów', 'tów', 'ign', [], []))]
# [(0, 1, ('kj', 'kj', 'ign', [], []))]
# [(0, 1, ('kpwig', 'kpwig', 'ign', [], []))]
# [(0, 1, ('teryto', 'teryto', 'ign', [], []))]
# [(0, 1, ('rialnego', 'rialnego', 'ign', [], []))]
# [(0, 1, ('zawart', 'zawart', 'ign', [], []))]
# [(0, 1, ('ośc', 'ośc', 'ign', [], []))]
# [(0, 1, ('ami', 'ami', 'ign', [], []))]
# [(0, 1, ('glinowo', 'glinowo', 'ign', [], []))]
# [(0, 1, ('ym', 'ym', 'ign', [], []))]
# [(0, 1, ('chelatującym', 'chelatującym', 'ign', [], []))]
# [(0, 1, ('najmnie', 'najmnie', 'ign', [], []))]
# [(0, 1, ('indentyfikacyjny', 'indentyfikacyjny', 'ign', [], []))]
# [(0, 1, ('blanco', 'blanco', 'ign', [], []))]
# [(0, 1, ('vesicular', 'vesicular', 'ign', [], []))]
# [(0, 1, ('rift', 'rift', 'ign', [], []))]
# [(0, 1, ('african', 'african', 'ign', [], []))]
# [(0, 1, ('encephalomyelitis', 'encephalomyelitis', 'ign', [], []))]
# [(0, 1, ('gumboro', 'gumboro', 'ign', [], []))]
# [(0, 1, ('haemorrhagic', 'haemorrhagic', 'ign', [], []))]
# [(0, 1, ('domesticus', 'domesticus', 'ign', [], []))]
# [(0, 1, ('szkolno', 'szkolno', 'ign', [], []))]
# [(0, 1, ('perry', 'perry', 'ign', [], []))]
# [(0, 1, ('reemitowania', 'reemitowania', 'ign', [], []))]
# [(0, 1, ('wych', 'wych', 'ign', [], []))]
# [(0, 1, ('czenia', 'czenia', 'ign', [], []))]
# [(0, 1, ('rekapitalizacji', 'rekapitalizacji', 'ign', [], []))]
# [(0, 1, ('ków', 'ków', 'ign', [], []))]
# [(0, 1, ('wykrywczych', 'wykrywczych', 'ign', [], []))]
# [(0, 1, ('zalądowionych', 'zalądowionych', 'ign', [], []))]
# [(0, 1, ('wieżomaszty', 'wieżomaszty', 'ign', [], []))]
# [(0, 1, ('owiewnych', 'owiewnych', 'ign', [], []))]
# [(0, 1, ('nitracyjne', 'nitracyjne', 'ign', [], []))]
# [(0, 1, ('odbieralnice', 'odbieralnice', 'ign', [], []))]
# [(0, 1, ('ponitracyjnego', 'ponitracyjnego', 'ign', [], []))]
# [(0, 1, ('wn', 'wn', 'ign', [], []))]
# [(0, 1, ('ekd', 'ekd', 'ign', [], []))]
# [(0, 1, ('kwiu', 'kwiu', 'ign', [], []))]
# [(0, 1, ('ortofotomapy', 'ortofotomapy', 'ign', [], []))]
# [(0, 1, ('substytutywny', 'substytutywny', 'ign', [], []))]
# [(0, 1, ('tirage', 'tirage', 'ign', [], []))]
# [(0, 1, ('expedition', 'expedition', 'ign', [], []))]
# [(0, 1, ('szcze', 'szcze', 'ign', [], []))]
# [(0, 1, ('protokoł', 'protokoł', 'ign', [], []))]
# [(0, 1, ('cp', 'cp', 'ign', [], []))]
# [(0, 1, ('dibenzo', 'dibenzo', 'ign', [], []))]
# [(0, 1, ('rybołóstwa', 'rybołóstwa', 'ign', [], []))]
# [(0, 1, ('geotechnicznych', 'geotechnicznych', 'ign', [], []))]
# [(0, 1, ('posadawiania', 'posadawiania', 'ign', [], []))]
# [(0, 1, ('uprawnio', 'uprawnio', 'ign', [], []))]
# [(0, 1, ('msv', 'msv', 'ign', [], []))]
# [(0, 1, ('cee', 'cee', 'ign', [], []))]
# [(0, 1, ('organic', 'organic', 'ign', [], []))]
# [(0, 1, ('psychologówstażystów', 'psychologówstażystów', 'ign', [], []))]
# [(0, 1, ('jw', 'jw', 'ign', [], []))]
# [(0, 1, ('ekoinfonet', 'ekoinfonet', 'ign', [], []))]
# [(0, 1, ('sapard', 'sapard', 'ign', [], []))]
# [(0, 1, ('dp', 'dp', 'ign', [], []))]
# [(0, 1, ('rehabilitacyjnousprawniającym', 'rehabilitacyjnousprawniającym', 'ign', [], []))]
# [(0, 1, ('emerytalno', 'emerytalno', 'ign', [], []))]
# [(0, 1, ('kazeinianów', 'kazeinianów', 'ign', [], []))]
# [(0, 1, ('ivb', 'ivb', 'ign', [], []))]
# [(0, 1, ('łips', 'łips', 'ign', [], []))]
# [(0, 1, ('kosmetykw', 'kosmetykw', 'ign', [], []))]
# [(0, 1, ('tissue', 'tissue', 'ign', [], []))]
# [(0, 1, ('harmoniowych', 'harmoniowych', 'ign', [], []))]
# [(0, 1, ('polonit', 'polonit', 'ign', [], []))]
# [(0, 1, ('polichlorowanych', 'polichlorowanych', 'ign', [], []))]
# [(0, 1, ('morządu', 'morządu', 'ign', [], []))]
# [(0, 1, ('torialnego', 'torialnego', 'ign', [], []))]
# [(0, 1, ('cirr', 'cirr', 'ign', [], []))]
# [(0, 1, ('ane', 'ane', 'ign', [], []))]
# [(0, 1, ('wapnio', 'wapnio', 'ign', [], []))]
# [(0, 1, ('nawozo', 'nawozo', 'ign', [], []))]
# [(0, 1, ('siarczano', 'siarczano', 'ign', [], []))]
# [(0, 1, ('zan', 'zan', 'ign', [], []))]
# [(0, 1, ('całkowit', 'całkowit', 'ign', [], []))]
# [(0, 1, ('dimocznik', 'dimocznik', 'ign', [], []))]
# [(0, 1, ('izobutylide', 'izobutylide', 'ign', [], []))]
# [(0, 1, ('cznika', 'cznika', 'ign', [], []))]
# [(0, 1, ('ek', 'ek', 'ign', [], []))]
# [(0, 1, ('przemysłow', 'przemysłow', 'ign', [], []))]
# [(0, 1, ('petermanna', 'petermanna', 'ign', [], []))]
# [(0, 1, ('amo', 'amo', 'ign', [], []))]
# [(0, 1, ('now', 'now', 'ign', [], []))]
# [(0, 1, ('wane', 'wane', 'ign', [], []))]
# [(0, 1, ('ik', 'ik', 'ign', [], []))]
# [(0, 1, ('zawar', 'zawar', 'ign', [], []))]
# [(0, 1, ('organicz', 'organicz', 'ign', [], []))]
# [(0, 1, ('pochodze', 'pochodze', 'ign', [], []))]
# [(0, 1, ('zwierzęc', 'zwierzęc', 'ign', [], []))]
# [(0, 1, ('nk', 'nk', 'ign', [], []))]
# [(0, 1, ('otrzymyw', 'otrzymyw', 'ign', [], []))]
# [(0, 1, ('ru', 'ru', 'ign', [], []))]
# [(0, 1, ('pochodz', 'pochodz', 'ign', [], []))]
# [(0, 1, ('pochodzeni', 'pochodzeni', 'ign', [], []))]
# [(0, 1, ('rozpuszczalneg', 'rozpuszczalneg', 'ign', [], []))]
# [(0, 1, ('rozpuszczalnoś', 'rozpuszczalnoś', 'ign', [], []))]
# [(0, 1, ('klasyfikac', 'klasyfikac', 'ign', [], []))]
# [(0, 1, ('molibdenia', 'molibdenia', 'ign', [], []))]
# [(0, 1, ('faxu', 'faxu', 'ign', [], []))]
# [(0, 1, ('laeq', 'laeq', 'ign', [], []))]
# [(0, 1, ('vol', 'vol', 'ign', [], []))]
# [(0, 1, ('hagera', 'hagera', 'ign', [], []))]
# [(0, 1, ('hydrolizatory', 'hydrolizatory', 'ign', [], []))]
# [(0, 1, ('sheep', 'sheep', 'ign', [], []))]
# [(0, 1, ('pox', 'pox', 'ign', [], []))]
# [(0, 1, ('highly', 'highly', 'ign', [], []))]
# [(0, 1, ('haematopoietic', 'haematopoietic', 'ign', [], []))]
# [(0, 1, ('necrosis', 'necrosis', 'ign', [], []))]
# [(0, 1, ('tuberculosis', 'tuberculosis', 'ign', [], []))]
# [(0, 1, ('abortus', 'abortus', 'ign', [], []))]
# [(0, 1, ('salmonelozy', 'salmonelozy', 'ign', [], []))]
# [(0, 1, ('salmonellosis', 'salmonellosis', 'ign', [], []))]
# [(0, 1, ('cattles', 'cattles', 'ign', [], []))]
# [(0, 1, ('pigs', 'pigs', 'ign', [], []))]
# [(0, 1, ('maedi', 'maedi', 'ign', [], []))]
# [(0, 1, ('visna', 'visna', 'ign', [], []))]
# [(0, 1, ('caprine', 'caprine', 'ign', [], []))]
# [(0, 1, ('mycoplasma', 'mycoplasma', 'ign', [], []))]
# [(0, 1, ('septicaemia', 'septicaemia', 'ign', [], []))]
# [(0, 1, ('szczecinświnoujście', 'szczecinświnoujście', 'ign', [], []))]
# [(0, 1, ('auschwitzbirkenau', 'auschwitzbirkenau', 'ign', [], []))]
# [(0, 1, ('publicz', 'publicz', 'ign', [], []))]
# [(0, 1, ('sędziemukomisarzowi', 'sędziemukomisarzowi', 'ign', [], []))]
# [(0, 1, ('kidawabłońska', 'kidawabłońska', 'ign', [], []))]
# [(0, 1, ('va', 'va', 'ign', [], []))]
# [(0, 1, ('farmakokinetyczne', 'farmakokinetyczne', 'ign', [], []))]
# [(0, 1, ('cztero', 'cztero', 'ign', [], []))]
# [(0, 1, ('ubezpie', 'ubezpie', 'ign', [], []))]
# [(0, 1, ('cde', 'cde', 'ign', [], []))]
# [(0, 1, ('chemicz', 'chemicz', 'ign', [], []))]
# [(0, 1, ('przecho', 'przecho', 'ign', [], []))]
# [(0, 1, ('sprzedaą', 'sprzedaą', 'ign', [], []))]
# [(0, 1, ('niektrych', 'niektrych', 'ign', [], []))]
# [(0, 1, ('terytorial', 'terytorial', 'ign', [], []))]
# [(0, 1, ('instrumentalistyki', 'instrumentalistyki', 'ign', [], []))]
# [(0, 1, ('pnen', 'pnen', 'ign', [], []))]
# [(0, 1, ('mie', 'mie', 'ign', [], []))]
# [(0, 1, ('rozmnożeniowego', 'rozmnożeniowego', 'ign', [], []))]
# [(0, 1, ('regazyfikacji', 'regazyfikacji', 'ign', [], []))]
# [(0, 1, ('pomiarowo', 'pomiarowo', 'ign', [], []))]
# [(0, 1, ('krśt', 'krśt', 'ign', [], []))]
# [(0, 1, ('ministremszefem', 'ministremszefem', 'ign', [], []))]
# [(0, 1, ('jastrzębiezdrój', 'jastrzębiezdrój', 'ign', [], []))]
# [(0, 1, ('trifenyle', 'trifenyle', 'ign', [], []))]
# [(0, 1, ('monometylotetrachlorodifenylometan', 'monometylotetrachlorodifenylometan', 'ign', [], []))]
# [(0, 1, ('monometylodichlorodifenylometan', 'monometylodichlorodifenylometan', 'ign', [], []))]
# [(0, 1, ('poeksploatacyjnych', 'poeksploatacyjnych', 'ign', [], []))]
# [(0, 1, ('wymienio', 'wymienio', 'ign', [], []))]
# [(0, 1, ('opcw', 'opcw', 'ign', [], []))]
# [(0, 1, ('winopodobne', 'winopodobne', 'ign', [], []))]
# [(0, 1, ('winopodobnych', 'winopodobnych', 'ign', [], []))]
# [(0, 1, ('pogórniczych', 'pogórniczych', 'ign', [], []))]
# [(0, 1, ('szczegól', 'szczegól', 'ign', [], []))]
# [(0, 1, ('piperydyna', 'piperydyna', 'ign', [], []))]
# [(0, 1, ('butylo', 'butylo', 'ign', [], []))]
# [(0, 1, ('morfolina', 'morfolina', 'ign', [], []))]
# [(0, 1, ('pirolidyna', 'pirolidyna', 'ign', [], []))]
# [(0, 1, ('petydyny', 'petydyny', 'ign', [], []))]
# [(0, 1, ('ołnierzy', 'ołnierzy', 'ign', [], []))]
# [(0, 1, ('brucellosis', 'brucellosis', 'ign', [], []))]
# [(0, 1, ('elim', 'elim', 'ign', [], []))]
# [(0, 1, ('betania', 'betania', 'ign', [], []))]
# [(0, 1, ('tele', 'tele', 'ign', [], []))]
# [(0, 1, ('ixa', 'ixa', 'ign', [], []))]
# [(0, 1, ('aw', 'aw', 'ign', [], []))]
# [(0, 1, ('cannabis', 'cannabis', 'ign', [], []))]
# [(0, 1, ('sativa', 'sativa', 'ign', [], []))]
# [(0, 1, ('pneumoniae', 'pneumoniae', 'ign', [], []))]
# [(0, 1, ('hbv', 'hbv', 'ign', [], []))]
# [(0, 1, ('species', 'species', 'ign', [], []))]
# [(0, 1, ('control', 'control', 'ign', [], []))]
# [(0, 1, ('apostille', 'apostille', 'ign', [], []))]
# [(0, 1, ('interkalibracyjnych', 'interkalibracyjnych', 'ign', [], []))]
# [(0, 1, ('ekoinfonetu', 'ekoinfonetu', 'ign', [], []))]
# [(0, 1, ('organizacyjno', 'organizacyjno', 'ign', [], []))]
# [(0, 1, ('eutc', 'eutc', 'ign', [], []))]
# [(0, 1, ('isbt', 'isbt', 'ign', [], []))]
# [(0, 1, ('belinyczechowskiego', 'belinyczechowskiego', 'ign', [], []))]
# [(0, 1, ('cza', 'cza', 'ign', [], []))]
# [(0, 1, ('zbywczą', 'zbywczą', 'ign', [], []))]
# [(0, 1, ('zbywczej', 'zbywczej', 'ign', [], []))]
# [(0, 1, ('gemeinschaft', 'gemeinschaft', 'ign', [], []))]
# [(0, 1, ('stilbenów', 'stilbenów', 'ign', [], []))]
# [(0, 1, ('iiii', 'iiii', 'ign', [], []))]
# [(0, 1, ('testw', 'testw', 'ign', [], []))]
# [(0, 1, ('składnikw', 'składnikw', 'ign', [], []))]
# [(0, 1, ('szczegłowe', 'szczegłowe', 'ign', [], []))]
# [(0, 1, ('orzecznikw', 'orzecznikw', 'ign', [], []))]
# [(0, 1, ('sce', 'sce', 'ign', [], []))]
# [(0, 1, ('ksow', 'ksow', 'ign', [], []))]
# [(0, 1, ('asistent', 'asistent', 'ign', [], []))]
# [(0, 1, ('medical', 'medical', 'ign', [], []))]
# [(0, 1, ('izotropowo', 'izotropowo', 'ign', [], []))]
# [(0, 1, ('domicylowy', 'domicylowy', 'ign', [], []))]
# [(0, 1, ('morpak', 'morpak', 'ign', [], []))]
# [(0, 1, ('cobrpib', 'cobrpib', 'ign', [], []))]
# [(0, 1, ('ności', 'ności', 'ign', [], []))]
# [(0, 1, ('ktry', 'ktry', 'ign', [], []))]
# [(0, 1, ('ghp', 'ghp', 'ign', [], []))]
# [(0, 1, ('gmp', 'gmp', 'ign', [], []))]
# [(0, 1, ('kpk', 'kpk', 'ign', [], []))]
# [(0, 1, ('agaricus', 'agaricus', 'ign', [], []))]
# [(0, 1, ('meslin', 'meslin', 'ign', [], []))]
# [(0, 1, ('przyłowu', 'przyłowu', 'ign', [], []))]
# [(0, 1, ('zas', 'zas', 'ign', [], []))]
# [(0, 1, ('trzeżeniem', 'trzeżeniem', 'ign', [], []))]
# [(0, 1, ('rytorialnego', 'rytorialnego', 'ign', [], []))]
# [(0, 1, ('gólności', 'gólności', 'ign', [], []))]
# [(0, 1, ('zadeklaro', 'zadeklaro', 'ign', [], []))]
# [(0, 1, ('żetowych', 'żetowych', 'ign', [], []))]
# [(0, 1, ('wanej', 'wanej', 'ign', [], []))]
# [(0, 1, ('daninowym', 'daninowym', 'ign', [], []))]
# [(0, 1, ('auditorów', 'auditorów', 'ign', [], []))]
# [(0, 1, ('deklarow', 'deklarow', 'ign', [], []))]
# [(0, 1, ('otrzymywa', 'otrzymywa', 'ign', [], []))]
# [(0, 1, ('osiarc', 'osiarc', 'ign', [], []))]
# [(0, 1, ('krotonylide', 'krotonylide', 'ign', [], []))]
# [(0, 1, ('nodimocznik', 'nodimocznik', 'ign', [], []))]
# [(0, 1, ('dimocznika', 'dimocznika', 'ign', [], []))]
# [(0, 1, ('naturalneg', 'naturalneg', 'ign', [], []))]
# [(0, 1, ('roztwo', 'roztwo', 'ign', [], []))]
# [(0, 1, ('kow', 'kow', 'ign', [], []))]
# [(0, 1, ('zwierzęceg', 'zwierzęceg', 'ign', [], []))]
# [(0, 1, ('enodimoczn', 'enodimoczn', 'ign', [], []))]
# [(0, 1, ('zu', 'zu', 'ign', [], []))]
# [(0, 1, ('cyjanamidowy', 'cyjanamidowy', 'ign', [], []))]
# [(0, 1, ('azotowo', 'azotowo', 'ign', [], []))]
# [(0, 1, ('chemiczn', 'chemiczn', 'ign', [], []))]
# [(0, 1, ('postac', 'postac', 'ign', [], []))]
# [(0, 1, ('cji', 'cji', 'ign', [], []))]
# [(0, 1, ('znych', 'znych', 'ign', [], []))]
# [(0, 1, ('enia', 'enia', 'ign', [], []))]
# [(0, 1, ('roślinn', 'roślinn', 'ign', [], []))]
# [(0, 1, ('cego', 'cego', 'ign', [], []))]
# [(0, 1, ('przeliczen', 'przeliczen', 'ign', [], []))]
# [(0, 1, ('iu', 'iu', 'ign', [], []))]
# [(0, 1, ('ia', 'ia', 'ign', [], []))]
# [(0, 1, ('oru', 'oru', 'ign', [], []))]
# [(0, 1, ('zawie', 'zawie', 'ign', [], []))]
# [(0, 1, ('lidenod', 'lidenod', 'ign', [], []))]
# [(0, 1, ('ureafor', 'ureafor', 'ign', [], []))]
# [(0, 1, ('rozpu', 'rozpu', 'ign', [], []))]
# [(0, 1, ('tość', 'tość', 'ign', [], []))]
# [(0, 1, ('dnego', 'dnego', 'ign', [], []))]
# [(0, 1, ('produ', 'produ', 'ign', [], []))]
# [(0, 1, ('ktu', 'ktu', 'ign', [], []))]
# [(0, 1, ('mikroeleme', 'mikroeleme', 'ign', [], []))]
# [(0, 1, ('kwadratowyc', 'kwadratowyc', 'ign', [], []))]
# [(0, 1, ('posodowe', 'posodowe', 'ign', [], []))]
# [(0, 1, ('posodowego', 'posodowego', 'ign', [], []))]
# [(0, 1, ('oprażonych', 'oprażonych', 'ign', [], []))]
# [(0, 1, ('tio', 'tio', 'ign', [], []))]
# [(0, 1, ('secret', 'secret', 'ign', [], []))]
# [(0, 1, ('cidr', 'cidr', 'ign', [], []))]
# [(0, 1, ('kupnasprzedaży', 'kupnasprzedaży', 'ign', [], []))]
# [(0, 1, ('poscaleniowego', 'poscaleniowego', 'ign', [], []))]
# [(0, 1, ('kontrolno', 'kontrolno', 'ign', [], []))]
# [(0, 1, ('foot', 'foot', 'ign', [], []))]
# [(0, 1, ('mouth', 'mouth', 'ign', [], []))]
# [(0, 1, ('stomatitis', 'stomatitis', 'ign', [], []))]
# [(0, 1, ('rinderpest', 'rinderpest', 'ign', [], []))]
# [(0, 1, ('peste', 'peste', 'ign', [], []))]
# [(0, 1, ('petits', 'petits', 'ign', [], []))]
# [(0, 1, ('ruminants', 'ruminants', 'ign', [], []))]
# [(0, 1, ('pleuropneumonia', 'pleuropneumonia', 'ign', [], []))]
# [(0, 1, ('valley', 'valley', 'ign', [], []))]
# [(0, 1, ('bluetongue', 'bluetongue', 'ign', [], []))]
# [(0, 1, ('goat', 'goat', 'ign', [], []))]
# [(0, 1, ('horse', 'horse', 'ign', [], []))]
# [(0, 1, ('sickness', 'sickness', 'ign', [], []))]
# [(0, 1, ('fowl', 'fowl', 'ign', [], []))]
# [(0, 1, ('plague', 'plague', 'ign', [], []))]
# [(0, 1, ('newcastle', 'newcastle', 'ign', [], []))]
# [(0, 1, ('enterowirusowe', 'enterowirusowe', 'ign', [], []))]
# [(0, 1, ('enterovirus', 'enterovirus', 'ign', [], []))]
# [(0, 1, ('ihn', 'ihn', 'ign', [], []))]
# [(0, 1, ('rabies', 'rabies', 'ign', [], []))]
# [(0, 1, ('anthrax', 'anthrax', 'ign', [], []))]
# [(0, 1, ('melitensis', 'melitensis', 'ign', [], []))]
# [(0, 1, ('enzootic', 'enzootic', 'ign', [], []))]
# [(0, 1, ('leucosis', 'leucosis', 'ign', [], []))]
# [(0, 1, ('spongiform', 'spongiform', 'ign', [], []))]
# [(0, 1, ('encephalopathy', 'encephalopathy', 'ign', [], []))]
# [(0, 1, ('american', 'american', 'ign', [], []))]
# [(0, 1, ('foulbrood', 'foulbrood', 'ign', [], []))]
# [(0, 1, ('paratuberculosis', 'paratuberculosis', 'ign', [], []))]
# [(0, 1, ('listeriosis', 'listeriosis', 'ign', [], []))]
# [(0, 1, ('toxoplasmosis', 'toxoplasmosis', 'ign', [], []))]
# [(0, 1, ('tularaemia', 'tularaemia', 'ign', [], []))]
# [(0, 1, ('glanders', 'glanders', 'ign', [], []))]
# [(0, 1, ('anaemia', 'anaemia', 'ign', [], []))]
# [(0, 1, ('metritis', 'metritis', 'ign', [], []))]
# [(0, 1, ('arteritis', 'arteritis', 'ign', [], []))]
# [(0, 1, ('dourine', 'dourine', 'ign', [], []))]
# [(0, 1, ('rhinotracheitis', 'rhinotracheitis', 'ign', [], []))]
# [(0, 1, ('pustular', 'pustular', 'ign', [], []))]
# [(0, 1, ('vulvovaginitis', 'vulvovaginitis', 'ign', [], []))]
# [(0, 1, ('mętwikowa', 'mętwikowa', 'ign', [], []))]
# [(0, 1, ('genital', 'genital', 'ign', [], []))]
# [(0, 1, ('rzęsistkowa', 'rzęsistkowa', 'ign', [], []))]
# [(0, 1, ('gastroenteritis', 'gastroenteritis', 'ign', [], []))]
# [(0, 1, ('scrapie', 'scrapie', 'ign', [], []))]
# [(0, 1, ('gruczolakowatość', 'gruczolakowatość', 'ign', [], []))]
# [(0, 1, ('ovine', 'ovine', 'ign', [], []))]
# [(0, 1, ('pulmonary', 'pulmonary', 'ign', [], []))]
# [(0, 1, ('adenomatosis', 'adenomatosis', 'ign', [], []))]
# [(0, 1, ('arthritis', 'arthritis', 'ign', [], []))]
# [(0, 1, ('encephalitis', 'encephalitis', 'ign', [], []))]
# [(0, 1, ('gallinarum', 'gallinarum', 'ign', [], []))]
# [(0, 1, ('pullorum', 'pullorum', 'ign', [], []))]
# [(0, 1, ('enteritidis', 'enteritidis', 'ign', [], []))]
# [(0, 1, ('typhimurium', 'typhimurium', 'ign', [], []))]
# [(0, 1, ('chlamydioza', 'chlamydioza', 'ign', [], []))]
# [(0, 1, ('chlamydiosis', 'chlamydiosis', 'ign', [], []))]
# [(0, 1, ('bursal', 'bursal', 'ign', [], []))]
# [(0, 1, ('mareka', 'mareka', 'ign', [], []))]
# [(0, 1, ('derzsy', 'derzsy', 'ign', [], []))]
# [(0, 1, ('gallisepticum', 'gallisepticum', 'ign', [], []))]
# [(0, 1, ('synoviae', 'synoviae', 'ign', [], []))]
# [(0, 1, ('myksomatoza', 'myksomatoza', 'ign', [], []))]
# [(0, 1, ('myxomatosis', 'myxomatosis', 'ign', [], []))]
# [(0, 1, ('rabbits', 'rabbits', 'ign', [], []))]
# [(0, 1, ('viraemia', 'viraemia', 'ign', [], []))]
# [(0, 1, ('carp', 'carp', 'ign', [], []))]
# [(0, 1, ('renibacteriosis', 'renibacteriosis', 'ign', [], []))]
# [(0, 1, ('anser', 'anser', 'ign', [], []))]
# [(0, 1, ('meleagris', 'meleagris', 'ign', [], []))]
# [(0, 1, ('coturnix', 'coturnix', 'ign', [], []))]
# [(0, 1, ('bubalus', 'bubalus', 'ign', [], []))]
# [(0, 1, ('bubalis', 'bubalis', 'ign', [], []))]
# [(0, 1, ('muzealium', 'muzealium', 'ign', [], []))]
# [(0, 1, ('reemitować', 'reemitować', 'ign', [], []))]
# [(0, 1, ('biobójczymi', 'biobójczymi', 'ign', [], []))]
# [(0, 1, ('finan', 'finan', 'ign', [], []))]
# [(0, 1, ('nicznego', 'nicznego', 'ign', [], []))]
# [(0, 1, ('porealizacyjne', 'porealizacyjne', 'ign', [], []))]
# [(0, 1, ('cyjnych', 'cyjnych', 'ign', [], []))]
# [(0, 1, ('indentyfikacyjnym', 'indentyfikacyjnym', 'ign', [], []))]
# [(0, 1, ('mjs', 'mjs', 'ign', [], []))]
# [(0, 1, ('kmh', 'kmh', 'ign', [], []))]
# [(0, 1, ('edukacyjno', 'edukacyjno', 'ign', [], []))]
# [(0, 1, ('mgkg', 'mgkg', 'ign', [], []))]
# [(0, 1, ('eluat', 'eluat', 'ign', [], []))]
# [(0, 1, ('farmakokinetycznych', 'farmakokinetycznych', 'ign', [], []))]
# [(0, 1, ('bezpie', 'bezpie', 'ign', [], []))]
# [(0, 1, ('dojelitowego', 'dojelitowego', 'ign', [], []))]
# [(0, 1, ('wydat', 'wydat', 'ign', [], []))]
# [(0, 1, ('czeniowych', 'czeniowych', 'ign', [], []))]
# [(0, 1, ('ivv', 'ivv', 'ign', [], []))]
# [(0, 1, ('juniorystów', 'juniorystów', 'ign', [], []))]
# [(0, 1, ('przedmiotw', 'przedmiotw', 'ign', [], []))]
# [(0, 1, ('środ', 'środ', 'ign', [], []))]
# [(0, 1, ('weteryna', 'weteryna', 'ign', [], []))]
# [(0, 1, ('pracownikw', 'pracownikw', 'ign', [], []))]
# [(0, 1, ('take', 'take', 'ign', [], []))]
# [(0, 1, ('państwagospodarza', 'państwagospodarza', 'ign', [], []))]
# [(0, 1, ('teryt', 'teryt', 'ign', [], []))]
# [(0, 1, ('wiednio', 'wiednio', 'ign', [], []))]
# [(0, 1, ('ycia', 'ycia', 'ign', [], []))]
# [(0, 1, ('gmdss', 'gmdss', 'ign', [], []))]
# [(0, 1, ('chemikali', 'chemikali', 'ign', [], []))]
# [(0, 1, ('odbieralnic', 'odbieralnic', 'ign', [], []))]
# [(0, 1, ('cyklotermicznych', 'cyklotermicznych', 'ign', [], []))]
# [(0, 1, ('fluidezyjne', 'fluidezyjne', 'ign', [], []))]
# [(0, 1, ('liczącopiszące', 'liczącopiszące', 'ign', [], []))]
# [(0, 1, ('ksipn', 'ksipn', 'ign', [], []))]
# [(0, 1, ('sprzeday', 'sprzeday', 'ign', [], []))]
# [(0, 1, ('obowiązkw', 'obowiązkw', 'ign', [], []))]
# [(0, 1, ('próbobiorcom', 'próbobiorcom', 'ign', [], []))]
# [(0, 1, ('instala', 'instala', 'ign', [], []))]
# [(0, 1, ('przeprowa', 'przeprowa', 'ign', [], []))]
# [(0, 1, ('dzonych', 'dzonych', 'ign', [], []))]
# [(0, 1, ('prefinansowaniem', 'prefinansowaniem', 'ign', [], []))]
# [(0, 1, ('cpc', 'cpc', 'ign', [], []))]
# [(0, 1, ('warszawaśródmieście', 'warszawaśródmieście', 'ign', [], []))]
# [(0, 1, ('monometylodibromodifenylometan', 'monometylodibromodifenylometan', 'ign', [], []))]
# [(0, 1, ('halogenowanych', 'halogenowanych', 'ign', [], []))]
# [(0, 1, ('polichlorowanego', 'polichlorowanego', 'ign', [], []))]
# [(0, 1, ('dibenzofuranu', 'dibenzofuranu', 'ign', [], []))]
# [(0, 1, ('polichlorowanej', 'polichlorowanej', 'ign', [], []))]
# [(0, 1, ('dibenzopdioksyny', 'dibenzopdioksyny', 'ign', [], []))]
# [(0, 1, ('kon', 'kon', 'ign', [], []))]
# [(0, 1, ('spo', 'spo', 'ign', [], []))]
# [(0, 1, ('etykietyinstrukcji', 'etykietyinstrukcji', 'ign', [], []))]
# [(0, 1, ('etykiecieinstrukcji', 'etykiecieinstrukcji', 'ign', [], []))]
# [(0, 1, ('ubojowca', 'ubojowca', 'ign', [], []))]
# [(0, 1, ('protected', 'protected', 'ign', [], []))]
# [(0, 1, ('doha', 'doha', 'ign', [], []))]
# [(0, 1, ('nastawu', 'nastawu', 'ign', [], []))]
# [(0, 1, ('półmusujące', 'półmusujące', 'ign', [], []))]
# [(0, 1, ('psr', 'psr', 'ign', [], []))]
# [(0, 1, ('businesseurope', 'businesseurope', 'ign', [], []))]
# [(0, 1, ('ueapme', 'ueapme', 'ign', [], []))]
# [(0, 1, ('ceep', 'ceep', 'ign', [], []))]
# [(0, 1, ('etuc', 'etuc', 'ign', [], []))]
# [(0, 1, ('oiml', 'oiml', 'ign', [], []))]
# [(0, 1, ('pźn', 'pźn', 'ign', [], []))]
# [(0, 1, ('dyspaszerskiego', 'dyspaszerskiego', 'ign', [], []))]
# [(0, 1, ('stornowej', 'stornowej', 'ign', [], []))]
# [(0, 1, ('hip', 'hip', 'ign', [], []))]
# [(0, 1, ('kava', 'kava', 'ign', [], []))]
# [(0, 1, ('mimosa', 'mimosa', 'ign', [], []))]
# [(0, 1, ('ntlenek', 'ntlenek', 'ign', [], []))]
# [(0, 1, ('piran', 'piran', 'ign', [], []))]
# [(0, 1, ('adimetylofenetyloamina', 'adimetylofenetyloamina', 'ign', [], []))]
# [(0, 1, ('retencjonowania', 'retencjonowania', 'ign', [], []))]
# [(0, 1, ('polarymetryczną', 'polarymetryczną', 'ign', [], []))]
# [(0, 1, ('rekonstytucji', 'rekonstytucji', 'ign', [], []))]
# [(0, 1, ('rpz', 'rpz', 'ign', [], []))]
# [(0, 1, ('rpw', 'rpw', 'ign', [], []))]
# [(0, 1, ('zawiesze', 'zawiesze', 'ign', [], []))]
# [(0, 1, ('ehv', 'ehv', 'ign', [], []))]
# [(0, 1, ('foul', 'foul', 'ign', [], []))]
# [(0, 1, ('brood', 'brood', 'ign', [], []))]
# [(0, 1, ('graniczej', 'graniczej', 'ign', [], []))]
# [(0, 1, ('statkówprzetwórni', 'statkówprzetwórni', 'ign', [], []))]
# [(0, 1, ('ministerkierownik', 'ministerkierownik', 'ign', [], []))]
# [(0, 1, ('ministremkierownikiem', 'ministremkierownikiem', 'ign', [], []))]
# [(0, 1, ('świad', 'świad', 'ign', [], []))]
# [(0, 1, ('wywanie', 'wywanie', 'ign', [], []))]
# [(0, 1, ('wizjofonu', 'wizjofonu', 'ign', [], []))]
# [(0, 1, ('wizjofonem', 'wizjofonem', 'ign', [], []))]
# [(0, 1, ('otwockuświerku', 'otwockuświerku', 'ign', [], []))]
# [(0, 1, ('maea', 'maea', 'ign', [], []))]
# [(0, 1, ('hydralizatory', 'hydralizatory', 'ign', [], []))]
# [(0, 1, ('inspekcyjno', 'inspekcyjno', 'ign', [], []))]
# [(0, 1, ('któ', 'któ', 'ign', [], []))]
# [(0, 1, ('rych', 'rych', 'ign', [], []))]
# [(0, 1, ('elastomerowej', 'elastomerowej', 'ign', [], []))]
# [(0, 1, ('cheater', 'cheater', 'ign', [], []))]
# [(0, 1, ('jacket', 'jacket', 'ign', [], []))]
# [(0, 1, ('fourcroydes', 'fourcroydes', 'ign', [], []))]
# [(0, 1, ('amaryllidaceae', 'amaryllidaceae', 'ign', [], []))]
# [(0, 1, ('mj', 'mj', 'ign', [], []))]
# [(0, 1, ('chlamydiozy', 'chlamydiozy', 'ign', [], []))]
# [(0, 1, ('haemophilus', 'haemophilus', 'ign', [], []))]
# [(0, 1, ('trichinella', 'trichinella', 'ign', [], []))]
# [(0, 1, ('yersinia', 'yersinia', 'ign', [], []))]
# [(0, 1, ('agricultura', 'agricultura', 'ign', [], []))]
# [(0, 1, ('ewgkontrollsystem', 'ewgkontrollsystem', 'ign', [], []))]
# [(0, 1, ('biologische', 'biologische', 'ign', [], []))]
# [(0, 1, ('ekologiskt', 'ekologiskt', 'ign', [], []))]
# [(0, 1, ('jordbruk', 'jordbruk', 'ign', [], []))]
# [(0, 1, ('eegkontrollsystem', 'eegkontrollsystem', 'ign', [], []))]
# [(0, 1, ('towego', 'towego', 'ign', [], []))]
# [(0, 1, ('cy', 'cy', 'ign', [], []))]
# [(0, 1, ('pra', 'pra', 'ign', [], []))]
# [(0, 1, ('ead', 'ead', 'ign', [], []))]
# [(0, 1, ('państwstron', 'państwstron', 'ign', [], []))]
# [(0, 1, ('poźn', 'poźn', 'ign', [], []))]
# [(0, 1, ('czenie', 'czenie', 'ign', [], []))]
# [(0, 1, ('lugano', 'lugano', 'ign', [], []))]
# [(0, 1, ('rehabilitacyjnousprawniające', 'rehabilitacyjnousprawniające', 'ign', [], []))]
# [(0, 1, ('szt', 'szt', 'ign', [], []))]
# [(0, 1, ('wk', 'wk', 'ign', [], []))]
# [(0, 1, ('eurocode', 'eurocode', 'ign', [], []))]
# [(0, 1, ('poltransplant', 'poltransplant', 'ign', [], []))]
# [(0, 1, ('nieniem', 'nieniem', 'ign', [], []))]
# [(0, 1, ('eurogendfor', 'eurogendfor', 'ign', [], []))]
# [(0, 1, ('velsen', 'velsen', 'ign', [], []))]
# [(0, 1, ('duchownychemerytów', 'duchownychemerytów', 'ign', [], []))]
# [(0, 1, ('itego', 'itego', 'ign', [], []))]
# [(0, 1, ('sanitacji', 'sanitacji', 'ign', [], []))]
# [(0, 1, ('methodistische', 'methodistische', 'ign', [], []))]
# [(0, 1, ('kirche', 'kirche', 'ign', [], []))]
# [(0, 1, ('evangelische', 'evangelische', 'ign', [], []))]
# [(0, 1, ('poliploidyzacji', 'poliploidyzacji', 'ign', [], []))]
# [(0, 1, ('tbt', 'tbt', 'ign', [], []))]
# [(0, 1, ('oestradiol', 'oestradiol', 'ign', [], []))]
# [(0, 1, ('estropodobne', 'estropodobne', 'ign', [], []))]
# [(0, 1, ('wycho', 'wycho', 'ign', [], []))]
# [(0, 1, ('swwkwiu', 'swwkwiu', 'ign', [], []))]
# [(0, 1, ('iiv', 'iiv', 'ign', [], []))]
# [(0, 1, ('wniosko', 'wniosko', 'ign', [], []))]
# [(0, 1, ('junioryści', 'junioryści', 'ign', [], []))]
# [(0, 1, ('montego', 'montego', 'ign', [], []))]
# [(0, 1, ('bay', 'bay', 'ign', [], []))]
# [(0, 1, ('bison', 'bison', 'ign', [], []))]
# [(0, 1, ('szczeglności', 'szczeglności', 'ign', [], []))]
# [(0, 1, ('nieprzekra', 'nieprzekra', 'ign', [], []))]
# [(0, 1, ('wspłpracy', 'wspłpracy', 'ign', [], []))]
# [(0, 1, ('arr', 'arr', 'ign', [], []))]
# [(0, 1, ('kowr', 'kowr', 'ign', [], []))]
# [(0, 1, ('viiixi', 'viiixi', 'ign', [], []))]
# [(0, 1, ('wulkanizatorskie', 'wulkanizatorskie', 'ign', [], []))]
# [(0, 1, ('gręplarstwo', 'gręplarstwo', 'ign', [], []))]
# [(0, 1, ('kożuszkarstwa', 'kożuszkarstwa', 'ign', [], []))]
# [(0, 1, ('naprawkowe', 'naprawkowe', 'ign', [], []))]
# [(0, 1, ('organmistrzostwa', 'organmistrzostwa', 'ign', [], []))]
# [(0, 1, ('mechani', 'mechani', 'ign', [], []))]
# [(0, 1, ('generalist', 'generalist', 'ign', [], []))]
# [(0, 1, ('warszawaokęcie', 'warszawaokęcie', 'ign', [], []))]
# [(0, 1, ('zizomeryzowanych', 'zizomeryzowanych', 'ign', [], []))]
# [(0, 1, ('zizomeryzowane', 'zizomeryzowane', 'ign', [], []))]
# [(0, 1, ('grossrosen', 'grossrosen', 'ign', [], []))]
# [(0, 1, ('promieniowana', 'promieniowana', 'ign', [], []))]
# [(0, 1, ('pzz', 'pzz', 'ign', [], []))]
# [(0, 1, ('guido', 'guido', 'ign', [], []))]
# [(0, 1, ('koncesjodawcę', 'koncesjodawcę', 'ign', [], []))]
# [(0, 1, ('koncesjodawcy', 'koncesjodawcy', 'ign', [], []))]
# [(0, 1, ('eudragmdp', 'eudragmdp', 'ign', [], []))]
# [(0, 1, ('retencjonowanie', 'retencjonowanie', 'ign', [], []))]
# [(0, 1, ('pct', 'pct', 'ign', [], []))]
# [(0, 1, ('nawz', 'nawz', 'ign', [], []))]
# [(0, 1, ('zagroenie', 'zagroenie', 'ign', [], []))]
# [(0, 1, ('nawoenia', 'nawoenia', 'ign', [], []))]
# [(0, 1, ('spoycia', 'spoycia', 'ign', [], []))]
# [(0, 1, ('przeciwskazań', 'przeciwskazań', 'ign', [], []))]
# [(0, 1, ('rolno', 'rolno', 'ign', [], []))]
# [(0, 1, ('tangeryny', 'tangeryny', 'ign', [], []))]
# [(0, 1, ('satsuma', 'satsuma', 'ign', [], []))]
# [(0, 1, ('wilkingi', 'wilkingi', 'ign', [], []))]
# [(0, 1, ('grzyboznawcy', 'grzyboznawcy', 'ign', [], []))]
# [(0, 1, ('cią', 'cią', 'ign', [], []))]
# [(0, 1, ('lng', 'lng', 'ign', [], []))]
# [(0, 1, ('euratom', 'euratom', 'ign', [], []))]
# [(0, 1, ('przyłów', 'przyłów', 'ign', [], []))]
# [(0, 1, ('powtrnego', 'powtrnego', 'ign', [], []))]
# [(0, 1, ('wanych', 'wanych', 'ign', [], []))]
# [(0, 1, ('zobowią', 'zobowią', 'ign', [], []))]
# [(0, 1, ('pdp', 'pdp', 'ign', [], []))]
# [(0, 1, ('gospodar', 'gospodar', 'ign', [], []))]
# [(0, 1, ('budże', 'budże', 'ign', [], []))]
# [(0, 1, ('towym', 'towym', 'ign', [], []))]
# [(0, 1, ('skiego', 'skiego', 'ign', [], []))]
# [(0, 1, ('zacią', 'zacią', 'ign', [], []))]
# [(0, 1, ('zacją', 'zacją', 'ign', [], []))]
# [(0, 1, ('naru', 'naru', 'ign', [], []))]
# [(0, 1, ('obo', 'obo', 'ign', [], []))]
# [(0, 1, ('kampali', 'kampali', 'ign', [], []))]
# [(0, 1, ('cytopatologii', 'cytopatologii', 'ign', [], []))]
# [(0, 1, ('icmpd', 'icmpd', 'ign', [], []))]
# [(0, 1, ('poszczeglnych', 'poszczeglnych', 'ign', [], []))]
# [(0, 1, ('konimpex', 'konimpex', 'ign', [], []))]
# [(0, 1, ('fąd', 'fąd', 'ign', [], []))]
# [(0, 1, ('lubowni', 'lubowni', 'ign', [], []))]
# [(0, 1, ('wapnioweg', 'wapnioweg', 'ign', [], []))]
# [(0, 1, ('an', 'an', 'ign', [], []))]
# [(0, 1, ('moczni', 'moczni', 'ign', [], []))]
# [(0, 1, ('mocznikapochodzącego', 'mocznikapochodzącego', 'ign', [], []))]
# [(0, 1, ('monomeryczny', 'monomeryczny', 'ign', [], []))]
# [(0, 1, ('denodimo', 'denodimo', 'ign', [], []))]
# [(0, 1, ('nitryfikacj', 'nitryfikacj', 'ign', [], []))]
# [(0, 1, ('cyjanogu', 'cyjanogu', 'ign', [], []))]
# [(0, 1, ('cyjanoguan', 'cyjanoguan', 'ign', [], []))]
# [(0, 1, ('cyjanoguanidynę', 'cyjanoguanidynę', 'ign', [], []))]
# [(0, 1, ('anidyny', 'anidyny', 'ign', [], []))]
# [(0, 1, ('idynę', 'idynę', 'ign', [], []))]
# [(0, 1, ('cyjanoguanidyny', 'cyjanoguanidyny', 'ign', [], []))]
# [(0, 1, ('ureaformem', 'ureaformem', 'ign', [], []))]
# [(0, 1, ('superf', 'superf', 'ign', [], []))]
# [(0, 1, ('osfat', 'osfat', 'ign', [], []))]
# [(0, 1, ('rozpuszczalnprzesiew', 'rozpuszczalnprzesiew', 'ign', [], []))]
# [(0, 1, ('kwasacho', 'kwasacho', 'ign', [], []))]
# [(0, 1, ('niu', 'niu', 'ign', [], []))]
# [(0, 1, ('czeniu', 'czeniu', 'ign', [], []))]
# [(0, 1, ('wyłączn', 'wyłączn', 'ign', [], []))]
# [(0, 1, ('fosfora', 'fosfora', 'ign', [], []))]
# [(0, 1, ('ących', 'ących', 'ign', [], []))]
# [(0, 1, ('krotonylid', 'krotonylid', 'ign', [], []))]
# [(0, 1, ('izobutylid', 'izobutylid', 'ign', [], []))]
# [(0, 1, ('ika', 'ika', 'ign', [], []))]
# [(0, 1, ('yli', 'yli', 'ign', [], []))]
# [(0, 1, ('afo', 'afo', 'ign', [], []))]
# [(0, 1, ('rmu', 'rmu', 'ign', [], []))]
# [(0, 1, ('roztwor', 'roztwor', 'ign', [], []))]
# [(0, 1, ('mechanic', 'mechanic', 'ign', [], []))]
# [(0, 1, ('zne', 'zne', 'ign', [], []))]
# [(0, 1, ('zmieszan', 'zmieszan', 'ign', [], []))]
# [(0, 1, ('odimocznika', 'odimocznika', 'ign', [], []))]
# [(0, 1, ('nkjeżeli', 'nkjeżeli', 'ign', [], []))]
# [(0, 1, ('procesi', 'procesi', 'ign', [], []))]
# [(0, 1, ('nym', 'nym', 'ign', [], []))]
# [(0, 1, ('rozpusz', 'rozpusz', 'ign', [], []))]
# [(0, 1, ('amidow', 'amidow', 'ign', [], []))]
# [(0, 1, ('aczają', 'aczają', 'ign', [], []))]
# [(0, 1, ('rozp', 'rozp', 'ign', [], []))]
# [(0, 1, ('uszc', 'uszc', 'ign', [], []))]
# [(0, 1, ('zaln', 'zaln', 'ign', [], []))]
# [(0, 1, ('wodz', 'wodz', 'ign', [], []))]
# [(0, 1, ('chlo', 'chlo', 'ign', [], []))]
# [(0, 1, ('dopusz', 'dopusz', 'ign', [], []))]
# [(0, 1, ('roztw', 'roztw', 'ign', [], []))]
# [(0, 1, ('zawi', 'zawi', 'ign', [], []))]
# [(0, 1, ('eraj', 'eraj', 'ign', [], []))]
# [(0, 1, ('azotano', 'azotano', 'ign', [], []))]
# [(0, 1, ('bezowdne', 'bezowdne', 'ign', [], []))]
# [(0, 1, ('termofosf', 'termofosf', 'ign', [], []))]
# [(0, 1, ('iden', 'iden', 'ign', [], []))]
# [(0, 1, ('odim', 'odim', 'ign', [], []))]
# [(0, 1, ('oczn', 'oczn', 'ign', [], []))]
# [(0, 1, ('imoczni', 'imoczni', 'ign', [], []))]
# [(0, 1, ('przynajmni', 'przynajmni', 'ign', [], []))]
# [(0, 1, ('zadekla', 'zadekla', 'ign', [], []))]
# [(0, 1, ('rowanej', 'rowanej', 'ign', [], []))]
# [(0, 1, ('bezow', 'bezow', 'ign', [], []))]
# [(0, 1, ('lności', 'lności', 'ign', [], []))]
# [(0, 1, ('lność', 'lność', 'ign', [], []))]
# [(0, 1, ('magnezow', 'magnezow', 'ign', [], []))]
# [(0, 1, ('any', 'any', 'ign', [], []))]
# [(0, 1, ('ntu', 'ntu', 'ign', [], []))]
# [(0, 1, ('tlenochlor', 'tlenochlor', 'ign', [], []))]
# [(0, 1, ('molibdenow', 'molibdenow', 'ign', [], []))]
# [(0, 1, ('wapniowoa', 'wapniowoa', 'ign', [], []))]
# [(0, 1, ('cw', 'cw', 'ign', [], []))]
# [(0, 1, ('timonier', 'timonier', 'ign', [], []))]
# [(0, 1, ('maritim', 'maritim', 'ign', [], []))]
# [(0, 1, ('avocat', 'avocat', 'ign', [], []))]
# [(0, 1, ('wdraa', 'wdraa', 'ign', [], []))]
# [(0, 1, ('fotokopiowania', 'fotokopiowania', 'ign', [], []))]
# [(0, 1, ('bohumina', 'bohumina', 'ign', [], []))]
# [(0, 1, ('minpułapek', 'minpułapek', 'ign', [], []))]
# [(0, 1, ('zelwerowicza', 'zelwerowicza', 'ign', [], []))]
# [(0, 1, ('emas', 'emas', 'ign', [], []))]
# [(0, 1, ('ea', 'ea', 'ign', [], []))]
# [(0, 1, ('eb', 'eb', 'ign', [], []))]
# [(0, 1, ('wewnątrzwsplnotowego', 'wewnątrzwsplnotowego', 'ign', [], []))]
# [(0, 1, ('wewnątrzwsplnotowej', 'wewnątrzwsplnotowej', 'ign', [], []))]
# [(0, 1, ('wojewdztwa', 'wojewdztwa', 'ign', [], []))]
# [(0, 1, ('babassu', 'babassu', 'ign', [], []))]
# [(0, 1, ('rzepikowy', 'rzepikowy', 'ign', [], []))]
# [(0, 1, ('reestryfikowane', 'reestryfikowane', 'ign', [], []))]
# [(0, 1, ('elaidynizowane', 'elaidynizowane', 'ign', [], []))]
# [(0, 1, ('chłodzącosmarującymi', 'chłodzącosmarującymi', 'ign', [], []))]
# [(0, 1, ('famae', 'famae', 'ign', [], []))]
# [(0, 1, ('fh', 'fh', 'ign', [], []))]
# [(0, 1, ('obsługowo', 'obsługowo', 'ign', [], []))]
# [(0, 1, ('mieszkalno', 'mieszkalno', 'ign', [], []))]
# [(0, 1, ('mującą', 'mującą', 'ign', [], []))]
# [(0, 1, ('podarującymi', 'podarującymi', 'ign', [], []))]
# [(0, 1, ('nosprawności', 'nosprawności', 'ign', [], []))]
# [(0, 1, ('poscaleniowe', 'poscaleniowe', 'ign', [], []))]
# [(0, 1, ('preryferyjnych', 'preryferyjnych', 'ign', [], []))]
# [(0, 1, ('geoficznych', 'geoficznych', 'ign', [], []))]
# [(0, 1, ('biliotekami', 'biliotekami', 'ign', [], []))]
# [(0, 1, ('ultrechckiej', 'ultrechckiej', 'ign', [], []))]
# [(0, 1, ('biskupordynariusz', 'biskupordynariusz', 'ign', [], []))]
# [(0, 1, ('biskupemordynariuszem', 'biskupemordynariuszem', 'ign', [], []))]
# [(0, 1, ('boryjskie', 'boryjskie', 'ign', [], []))]
# [(0, 1, ('nepryski', 'nepryski', 'ign', [], []))]
# [(0, 1, ('boguszówgorce', 'boguszówgorce', 'ign', [], []))]
# [(0, 1, ('dusznikizdrój', 'dusznikizdrój', 'ign', [], []))]
# [(0, 1, ('ceidg', 'ceidg', 'ign', [], []))]
# [(0, 1, ('sanitarnoweterynaryjnye', 'sanitarnoweterynaryjnye', 'ign', [], []))]
# [(0, 1, ('niespełniają', 'niespełniają', 'ign', [], []))]
# [(0, 1, ('biologiczengo', 'biologiczengo', 'ign', [], []))]
# [(0, 1, ('sanitarnoepizootiologicznej', 'sanitarnoepizootiologicznej', 'ign', [], []))]
# [(0, 1, ('clasical', 'clasical', 'ign', [], []))]
# [(0, 1, ('pathogenic', 'pathogenic', 'ign', [], []))]
# [(0, 1, ('taflańska', 'taflańska', 'ign', [], []))]
# [(0, 1, ('suis', 'suis', 'ign', [], []))]
# [(0, 1, ('ovis', 'ovis', 'ign', [], []))]
# [(0, 1, ('infetious', 'infetious', 'ign', [], []))]
# [(0, 1, ('campylobacterosis', 'campylobacterosis', 'ign', [], []))]
# [(0, 1, ('trichomonosis', 'trichomonosis', 'ign', [], []))]
# [(0, 1, ('transmissible', 'transmissible', 'ign', [], []))]
# [(0, 1, ('trichinellosis', 'trichinellosis', 'ign', [], []))]
# [(0, 1, ('bezmleczność', 'bezmleczność', 'ign', [], []))]
# [(0, 1, ('agalactia', 'agalactia', 'ign', [], []))]
# [(0, 1, ('maedivisna', 'maedivisna', 'ign', [], []))]
# [(0, 1, ('lymphadenitis', 'lymphadenitis', 'ign', [], []))]
# [(0, 1, ('salmoneloza', 'salmoneloza', 'ign', [], []))]
# [(0, 1, ('arizone', 'arizone', 'ign', [], []))]
# [(0, 1, ('mykoplazmozy', 'mykoplazmozy', 'ign', [], []))]
# [(0, 1, ('meleagridis', 'meleagridis', 'ign', [], []))]
# [(0, 1, ('mycoplasmosis', 'mycoplasmosis', 'ign', [], []))]
# [(0, 1, ('mink', 'mink', 'ign', [], []))]
# [(0, 1, ('virus', 'virus', 'ign', [], []))]
# [(0, 1, ('enteritis', 'enteritis', 'ign', [], []))]
# [(0, 1, ('aleution', 'aleution', 'ign', [], []))]
# [(0, 1, ('hemorrhagenic', 'hemorrhagenic', 'ign', [], []))]
# [(0, 1, ('waroza', 'waroza', 'ign', [], []))]
# [(0, 1, ('varroosis', 'varroosis', 'ign', [], []))]
# [(0, 1, ('acariosis', 'acariosis', 'ign', [], []))]
# [(0, 1, ('bees', 'bees', 'ign', [], []))]
# [(0, 1, ('distemper', 'distemper', 'ign', [], []))]
# [(0, 1, ('anas', 'anas', 'ign', [], []))]
# [(0, 1, ('platyrchynchos', 'platyrchynchos', 'ign', [], []))]
# [(0, 1, ('cairina', 'cairina', 'ign', [], []))]
# [(0, 1, ('moschata', 'moschata', 'ign', [], []))]
# [(0, 1, ('gallopavo', 'gallopavo', 'ign', [], []))]
# [(0, 1, ('japonica', 'japonica', 'ign', [], []))]
# [(0, 1, ('numida', 'numida', 'ign', [], []))]
# [(0, 1, ('struthio', 'struthio', 'ign', [], []))]
# [(0, 1, ('camelus', 'camelus', 'ign', [], []))]
# [(0, 1, ('isbc', 'isbc', 'ign', [], []))]
# [(0, 1, ('waho', 'waho', 'ign', [], []))]
# [(0, 1, ('krzyżowniczych', 'krzyżowniczych', 'ign', [], []))]
# [(0, 1, ('krzyżownicze', 'krzyżownicze', 'ign', [], []))]
# [(0, 1, ('krzyżowniczym', 'krzyżowniczym', 'ign', [], []))]
# [(0, 1, ('inte', 'inte', 'ign', [], []))]
# [(0, 1, ('gracyjnymi', 'gracyjnymi', 'ign', [], []))]
# [(0, 1, ('społeczno', 'społeczno', 'ign', [], []))]
# [(0, 1, ('logii', 'logii', 'ign', [], []))]
# [(0, 1, ('przepro', 'przepro', 'ign', [], []))]
# [(0, 1, ('wadza', 'wadza', 'ign', [], []))]
# [(0, 1, ('eksplozymetrycznych', 'eksplozymetrycznych', 'ign', [], []))]
# [(0, 1, ('soraz', 'soraz', 'ign', [], []))]
# [(0, 1, ('isaf', 'isaf', 'ign', [], []))]
# [(0, 1, ('reemitowaniem', 'reemitowaniem', 'ign', [], []))]
# [(0, 1, ('słowno', 'słowno', 'ign', [], []))]
# [(0, 1, ('reemitowanie', 'reemitowanie', 'ign', [], []))]
# [(0, 1, ('pozorolniczych', 'pozorolniczych', 'ign', [], []))]
# [(0, 1, ('codzoziemcowi', 'codzoziemcowi', 'ign', [], []))]
# [(0, 1, ('pla', 'pla', 'ign', [], []))]
# [(0, 1, ('agro', 'agro', 'ign', [], []))]
# [(0, 1, ('sowych', 'sowych', 'ign', [], []))]
# [(0, 1, ('dofinan', 'dofinan', 'ign', [], []))]
# [(0, 1, ('sowanie', 'sowanie', 'ign', [], []))]
# [(0, 1, ('zapla', 'zapla', 'ign', [], []))]
# [(0, 1, ('nowane', 'nowane', 'ign', [], []))]
# [(0, 1, ('adminis', 'adminis', 'ign', [], []))]
# [(0, 1, ('naczone', 'naczone', 'ign', [], []))]
# [(0, 1, ('ciastkar', 'ciastkar', 'ign', [], []))]
# [(0, 1, ('wypo', 'wypo', 'ign', [], []))]
# [(0, 1, ('ste', 'ste', 'ign', [], []))]
# [(0, 1, ('organuwskazanie', 'organuwskazanie', 'ign', [], []))]
# [(0, 1, ('konflików', 'konflików', 'ign', [], []))]
# [(0, 1, ('postępo', 'postępo', 'ign', [], []))]
# [(0, 1, ('związ', 'związ', 'ign', [], []))]
# [(0, 1, ('kowej', 'kowej', 'ign', [], []))]
# [(0, 1, ('dziernika', 'dziernika', 'ign', [], []))]
# [(0, 1, ('oddziaływujących', 'oddziaływujących', 'ign', [], []))]
# [(0, 1, ('wew', 'wew', 'ign', [], []))]
# [(0, 1, ('nętrznych', 'nętrznych', 'ign', [], []))]
# [(0, 1, ('turystyczno', 'turystyczno', 'ign', [], []))]
# [(0, 1, ('gogiczny', 'gogiczny', 'ign', [], []))]
# [(0, 1, ('funkcjonalno', 'funkcjonalno', 'ign', [], []))]
# [(0, 1, ('obwodnicowe', 'obwodnicowe', 'ign', [], []))]
# [(0, 1, ('utrzymaniowych', 'utrzymaniowych', 'ign', [], []))]
# [(0, 1, ('goedezji', 'goedezji', 'ign', [], []))]
# [(0, 1, ('jowymi', 'jowymi', 'ign', [], []))]
# [(0, 1, ('hostelowych', 'hostelowych', 'ign', [], []))]
# [(0, 1, ('adopcyjno', 'adopcyjno', 'ign', [], []))]
# [(0, 1, ('apewnianie', 'apewnianie', 'ign', [], []))]
# [(0, 1, ('chrony', 'chrony', 'ign', [], []))]
# [(0, 1, ('wyaz', 'wyaz', 'ign', [], []))]
# [(0, 1, ('biorstwa', 'biorstwa', 'ign', [], []))]
# [(0, 1, ('try', 'try', 'ign', [], []))]
# [(0, 1, ('bie', 'bie', 'ign', [], []))]
# ...
# [(0, 1, ('wzbogaconyzawartość', 'wzbogaconyzawartość', 'ign', [], []))]
# [(0, 1, ('ntrowa', 'ntrowa', 'ign', [], []))]
# [(0, 1, ('ortofosforan', 'ortofosforan', 'ign', [], []))]
# [(0, 1, ('rozpuszczalnynawozu', 'rozpuszczalnynawozu', 'ign', [], []))]
# [(0, 1, ('odczynnikuprzesiew', 'odczynnikuprzesiew', 'ign', [], []))]
# [(0, 1, ('dwuwap', 'dwuwap', 'ign', [], []))]
# [(0, 1, ('petermannao', 'petermannao', 'ign', [], []))]
# [(0, 1, ('niowy', 'niowy', 'ign', [], []))]
# [(0, 1, ('dwuwod', 'dwuwod', 'ign', [], []))]
# [(0, 1, ('ytowe', 'ytowe', 'ign', [], []))]
# [(0, 1, ('mrówkoweg', 'mrówkoweg', 'ign', [], []))]
# [(0, 1, ('ązkowo', 'ązkowo', 'ign', [], []))]
# [(0, 1, ('potasuzawartość', 'potasuzawartość', 'ign', [], []))]
# [(0, 1, ('przelicze', 'przelicze', 'ign', [], []))]
# [(0, 1, ('odpowiedn', 'odpowiedn', 'ign', [], []))]
# [(0, 1, ('io', 'io', 'ign', [], []))]
# [(0, 1, ('przekracz', 'przekracz', 'ign', [], []))]
# [(0, 1, ('przelisiarc', 'przelisiarc', 'ign', [], []))]
# [(0, 1, ('przelizawierając', 'przelizawierając', 'ign', [], []))]
# [(0, 1, ('mechaniczn', 'mechaniczn', 'ign', [], []))]
# [(0, 1, ('cyjanamido', 'cyjanamido', 'ign', [], []))]
# [(0, 1, ('substancjinajmniej', 'substancjinajmniej', 'ign', [], []))]
# [(0, 1, ('pochodzeniprzeliczeniu', 'pochodzeniprzeliczeniu', 'ign', [], []))]
# [(0, 1, ('deg', 'deg', 'ign', [], []))]
# [(0, 1, ('cyj', 'cyj', 'ign', [], []))]
# [(0, 1, ('ana', 'ana', 'ign', [], []))]
# [(0, 1, ('glinowonajmniej', 'glinowonajmniej', 'ign', [], []))]
# [(0, 1, ('zawierawapniowego', 'zawierawapniowego', 'ign', [], []))]
# [(0, 1, ('jący', 'jący', 'ign', [], []))]
# [(0, 1, ('okreś', 'okreś', 'ign', [], []))]
# [(0, 1, ('lone', 'lone', 'ign', [], []))]
# [(0, 1, ('ideno', 'ideno', 'ign', [], []))]
# [(0, 1, ('dimoczni', 'dimoczni', 'ign', [], []))]
# [(0, 1, ('organicznyazotu', 'organicznyazotu', 'ign', [], []))]
# [(0, 1, ('pochodzenico', 'pochodzenico', 'ign', [], []))]
# [(0, 1, ('roślinnegofosforu', 'roślinnegofosforu', 'ign', [], []))]
# [(0, 1, ('nodimoczni', 'nodimoczni', 'ign', [], []))]
# [(0, 1, ('zwierzęcegna', 'zwierzęcegna', 'ign', [], []))]
# [(0, 1, ('zawierającnajmniej', 'zawierającnajmniej', 'ign', [], []))]
# [(0, 1, ('krotonyli', 'krotonyli', 'ign', [], []))]
# [(0, 1, ('denodimoc', 'denodimoc', 'ign', [], []))]
# [(0, 1, ('deno', 'deno', 'ign', [], []))]
# [(0, 1, ('odi', 'odi', 'ign', [], []))]
# [(0, 1, ('czn', 'czn', 'ign', [], []))]
# [(0, 1, ('oalne', 'oalne', 'ign', [], []))]
# [(0, 1, ('dim', 'dim', 'ign', [], []))]
# [(0, 1, ('aje', 'aje', 'ign', [], []))]
# [(0, 1, ('okr', 'okr', 'ign', [], []))]
# [(0, 1, ('eśl', 'eśl', 'ign', [], []))]
# [(0, 1, ('umn', 'umn', 'ign', [], []))]
# [(0, 1, ('ciśnieniemazotu', 'ciśnieniemazotu', 'ign', [], []))]
# [(0, 1, ('atmosferyczn', 'atmosferyczn', 'ign', [], []))]
# [(0, 1, ('substancjifosforu', 'substancjifosforu', 'ign', [], []))]
# [(0, 1, ('organiczprzeliczeniu', 'organiczprzeliczeniu', 'ign', [], []))]
# [(0, 1, ('pochodzeniaco', 'pochodzeniaco', 'ign', [], []))]
# [(0, 1, ('wys', 'wys', 'ign', [], []))]
# [(0, 1, ('ują', 'ują', 'ign', [], []))]
# [(0, 1, ('pos', 'pos', 'ign', [], []))]
# [(0, 1, ('inn', 'inn', 'ign', [], []))]
# [(0, 1, ('zwi', 'zwi', 'ign', [], []))]
# [(0, 1, ('ązk', 'ązk', 'ign', [], []))]
# [(0, 1, ('ier', 'ier', 'ign', [], []))]
# [(0, 1, ('ają', 'ają', 'ign', [], []))]
# [(0, 1, ('tości', 'tości', 'ign', [], []))]
# [(0, 1, ('najmn', 'najmn', 'ign', [], []))]
# [(0, 1, ('roztworz', 'roztworz', 'ign', [], []))]
# [(0, 1, ('iej', 'iej', 'ign', [], []))]
# [(0, 1, ('azota', 'azota', 'ign', [], []))]
# [(0, 1, ('amono', 'amono', 'ign', [], []))]
# [(0, 1, ('amido', 'amido', 'ign', [], []))]
# [(0, 1, ('glinowofosfor', 'glinowofosfor', 'ign', [], []))]
# [(0, 1, ('deklaro', 'deklaro', 'ign', [], []))]
# [(0, 1, ('pochodzeniapotasu', 'pochodzeniapotasu', 'ign', [], []))]
# [(0, 1, ('roślinnegoprzeliczeniu', 'roślinnegoprzeliczeniu', 'ign', [], []))]
# [(0, 1, ('krotonyliden', 'krotonyliden', 'ign', [], []))]
# [(0, 1, ('nieprzek', 'nieprzek', 'ign', [], []))]
# [(0, 1, ('raczając', 'raczając', 'ign', [], []))]
# [(0, 1, ('izobutyliden', 'izobutyliden', 'ign', [], []))]
# [(0, 1, ('krotonylidenomo', 'krotonylidenomo', 'ign', [], []))]
# [(0, 1, ('pozostałyc', 'pozostałyc', 'ign', [], []))]
# [(0, 1, ('izobutylidenodi', 'izobutylidenodi', 'ign', [], []))]
# [(0, 1, ('przypadk', 'przypadk', 'ign', [], []))]
# [(0, 1, ('najmni', 'najmni', 'ign', [], []))]
# [(0, 1, ('ciśnien', 'ciśnien', 'ign', [], []))]
# [(0, 1, ('iem', 'iem', 'ign', [], []))]
# [(0, 1, ('potasowyc', 'potasowyc', 'ign', [], []))]
# [(0, 1, ('atmosfe', 'atmosfe', 'ign', [], []))]
# [(0, 1, ('rycznym', 'rycznym', 'ign', [], []))]
# [(0, 1, ('nieprzekr', 'nieprzekr', 'ign', [], []))]
# [(0, 1, ('cą', 'cą', 'ign', [], []))]
# [(0, 1, ('bezwodneg', 'bezwodneg', 'ign', [], []))]
# [(0, 1, ('zawies', 'zawies', 'ign', [], []))]
# [(0, 1, ('iny', 'iny', 'ign', [], []))]
# [(0, 1, ('nawozow', 'nawozow', 'ign', [], []))]
# [(0, 1, ('fosforowo', 'fosforowo', 'ign', [], []))]
# [(0, 1, ('deklar', 'deklar', 'ign', [], []))]
# [(0, 1, ('owanie', 'owanie', 'ign', [], []))]
# [(0, 1, ('czne', 'czne', 'ign', [], []))]
# [(0, 1, ('przekr', 'przekr', 'ign', [], []))]
# [(0, 1, ('cej', 'cej', 'ign', [], []))]
# [(0, 1, ('enie', 'enie', 'ign', [], []))]
# [(0, 1, ('okre', 'okre', 'ign', [], []))]
# [(0, 1, ('ślona', 'ślona', 'ign', [], []))]
# [(0, 1, ('glinowoprzesiew', 'glinowoprzesiew', 'ign', [], []))]
# [(0, 1, ('nawoz', 'nawoz', 'ign', [], []))]
# [(0, 1, ('rozpuszczrozpuszczalny', 'rozpuszczrozpuszczalny', 'ign', [], []))]
# [(0, 1, ('wwodzie', 'wwodzie', 'ign', [], []))]
# [(0, 1, ('rozpuszcze', 'rozpuszcze', 'ign', [], []))]
# [(0, 1, ('atmosferyc', 'atmosferyc', 'ign', [], []))]
# [(0, 1, ('znym', 'znym', 'ign', [], []))]
# [(0, 1, ('rozpuszczalnrozpuszcz', 'rozpuszczalnrozpuszcz', 'ign', [], []))]
# [(0, 1, ('całkow', 'całkow', 'ign', [], []))]
# [(0, 1, ('fosf', 'fosf', 'ign', [], []))]
# [(0, 1, ('or', 'or', 'ign', [], []))]
# [(0, 1, ('cyjanam', 'cyjanam', 'ign', [], []))]
# [(0, 1, ('idowy', 'idowy', 'ign', [], []))]
# [(0, 1, ('rozpuszczalnośs', 'rozpuszczalnośs', 'ign', [], []))]
# [(0, 1, ('wi', 'wi', 'ign', [], []))]
# [(0, 1, ('alnego', 'alnego', 'ign', [], []))]
# [(0, 1, ('alność', 'alność', 'ign', [], []))]
# [(0, 1, ('zawiemineralnych', 'zawiemineralnych', 'ign', [], []))]
# [(0, 1, ('glinowowap', 'glinowowap', 'ign', [], []))]
# [(0, 1, ('niowego', 'niowego', 'ign', [], []))]
# [(0, 1, ('fosforowg', 'fosforowg', 'ign', [], []))]
# [(0, 1, ('rozzawi', 'rozzawi', 'ign', [], []))]
# [(0, 1, ('przeliczeniuazot', 'przeliczeniuazot', 'ign', [], []))]
# [(0, 1, ('onyl', 'onyl', 'ign', [], []))]
# [(0, 1, ('izob', 'izob', 'ign', [], []))]
# [(0, 1, ('utyl', 'utyl', 'ign', [], []))]
# [(0, 1, ('zawierajfosforu', 'zawierajfosforu', 'ign', [], []))]
# [(0, 1, ('izobu', 'izobu', 'ign', [], []))]
# [(0, 1, ('tylidenodimo', 'tylidenodimo', 'ign', [], []))]
# [(0, 1, ('urea', 'urea', 'ign', [], []))]
# [(0, 1, ('krotonylna', 'krotonylna', 'ign', [], []))]
# [(0, 1, ('rozpuszczalnośk', 'rozpuszczalnośk', 'ign', [], []))]
# [(0, 1, ('denodimonajmniej', 'denodimonajmniej', 'ign', [], []))]
# [(0, 1, ('wl', 'wl', 'ign', [], []))]
# [(0, 1, ('cznik', 'cznik', 'ign', [], []))]
# [(0, 1, ('izobutylpotasu', 'izobutylpotasu', 'ign', [], []))]
# [(0, 1, ('idenoprzeliczeniu', 'idenoprzeliczeniu', 'ign', [], []))]
# [(0, 1, ('dimocznina', 'dimocznina', 'ign', [], []))]
# [(0, 1, ('puszczalność', 'puszczalność', 'ign', [], []))]
# [(0, 1, ('ić', 'ić', 'ign', [], []))]
# [(0, 1, ('czalne', 'czalne', 'ign', [], []))]
# [(0, 1, ('atmosferyazotu', 'atmosferyazotu', 'ign', [], []))]
# [(0, 1, ('jeżel', 'jeżel', 'ign', [], []))]
# [(0, 1, ('cznym', 'cznym', 'ign', [], []))]
# [(0, 1, ('dodatkuco', 'dodatkuco', 'ign', [], []))]
# [(0, 1, ('chl', 'chl', 'ign', [], []))]
# [(0, 1, ('organicznzawartość', 'organicznzawartość', 'ign', [], []))]
# [(0, 1, ('pochodzenprzeliczeniu', 'pochodzenprzeliczeniu', 'ign', [], []))]
# [(0, 1, ('roślinneg', 'roślinneg', 'ign', [], []))]
# [(0, 1, ('deklarowan', 'deklarowan', 'ign', [], []))]
# [(0, 1, ('rozpuszczcałkowit', 'rozpuszczcałkowit', 'ign', [], []))]
# [(0, 1, ('łe', 'łe', 'ign', [], []))]
# [(0, 1, ('któr', 'któr', 'ign', [], []))]
# [(0, 1, ('dopu', 'dopu', 'ign', [], []))]
# [(0, 1, ('kolumnieszcz', 'kolumnieszcz', 'ign', [], []))]
# [(0, 1, ('skła', 'skła', 'ign', [], []))]
# [(0, 1, ('pkta', 'pkta', 'ign', [], []))]
# [(0, 1, ('dnik', 'dnik', 'ign', [], []))]
# [(0, 1, ('czymdekl', 'czymdekl', 'ign', [], []))]
# [(0, 1, ('arow', 'arow', 'ign', [], []))]
# [(0, 1, ('zowe', 'zowe', 'ign', [], []))]
# [(0, 1, ('zawa', 'zawa', 'ign', [], []))]
# [(0, 1, ('rtoś', 'rtoś', 'ign', [], []))]
# [(0, 1, ('bezwo', 'bezwo', 'ign', [], []))]
# [(0, 1, ('rozt', 'rozt', 'ign', [], []))]
# [(0, 1, ('esin', 'esin', 'ign', [], []))]
# [(0, 1, ('wodn', 'wodn', 'ign', [], []))]
# [(0, 1, ('tku', 'tku', 'ign', [], []))]
# [(0, 1, ('subs', 'subs', 'ign', [], []))]
# [(0, 1, ('tanc', 'tanc', 'ign', [], []))]
# [(0, 1, ('orga', 'orga', 'ign', [], []))]
# [(0, 1, ('odze', 'odze', 'ign', [], []))]
# [(0, 1, ('rośl', 'rośl', 'ign', [], []))]
# [(0, 1, ('rzęc', 'rzęc', 'ign', [], []))]
# [(0, 1, ('termofosfa', 'termofosfa', 'ign', [], []))]
# [(0, 1, ('rozłożoneg', 'rozłożoneg', 'ign', [], []))]
# [(0, 1, ('elementarnato', 'elementarnato', 'ign', [], []))]
# [(0, 1, ('mineralnyc', 'mineralnyc', 'ign', [], []))]
# [(0, 1, ('fertygacji', 'fertygacji', 'ign', [], []))]
# [(0, 1, ('wapniowoprzeliczeniu', 'wapniowoprzeliczeniu', 'ign', [], []))]
# [(0, 1, ('wapniowomagnezow', 'wapniowomagnezow', 'ign', [], []))]
# [(0, 1, ('borowyja', 'borowyja', 'ign', [], []))]
# [(0, 1, ('przedmioto', 'przedmioto', 'ign', [], []))]
# [(0, 1, ('uzależnion', 'uzależnion', 'ign', [], []))]
# [(0, 1, ('sodow', 'sodow', 'ign', [], []))]
# [(0, 1, ('wapniajest', 'wapniajest', 'ign', [], []))]
# [(0, 1, ('kolemanitu', 'kolemanitu', 'ign', [], []))]
# [(0, 1, ('pandermitu', 'pandermitu', 'ign', [], []))]
# [(0, 1, ('klasyfikow', 'klasyfikow', 'ign', [], []))]
# [(0, 1, ('boroetanol', 'boroetanol', 'ign', [], []))]
# [(0, 1, ('oaminadodatek', 'oaminadodatek', 'ign', [], []))]
# [(0, 1, ('etanoloaminą', 'etanoloaminą', 'ign', [], []))]
# [(0, 1, ('etanoloaminy', 'etanoloaminy', 'ign', [], []))]
# [(0, 1, ('wzasadniczy', 'wzasadniczy', 'ign', [], []))]
# [(0, 1, ('postaciklasyfikow', 'postaciklasyfikow', 'ign', [], []))]
# [(0, 1, ('boroetanoloaminy', 'boroetanoloaminy', 'ign', [], []))]
# [(0, 1, ('kobaltuprzypadek', 'kobaltuprzypadek', 'ign', [], []))]
# [(0, 1, ('rozpatrywa', 'rozpatrywa', 'ign', [], []))]
# [(0, 1, ('jednostkow', 'jednostkow', 'ign', [], []))]
# [(0, 1, ('kobaltoweg', 'kobaltoweg', 'ign', [], []))]
# [(0, 1, ('wodorotlen', 'wodorotlen', 'ign', [], []))]
# [(0, 1, ('miedzioweg', 'miedzioweg', 'ign', [], []))]
# [(0, 1, ('tleno', 'tleno', 'ign', [], []))]
# [(0, 1, ('tlene', 'tlene', 'ign', [], []))]
# [(0, 1, ('fikowany', 'fikowany', 'ign', [], []))]
# [(0, 1, ('normalizu', 'normalizu', 'ign', [], []))]
# [(0, 1, ('najniej', 'najniej', 'ign', [], []))]
# [(0, 1, ('normali', 'normali', 'ign', [], []))]
# [(0, 1, ('zuje', 'zuje', 'ign', [], []))]
# [(0, 1, ('molibde', 'molibde', 'ign', [], []))]
# [(0, 1, ('menty', 'menty', 'ign', [], []))]
# [(0, 1, ('wymi', 'wymi', 'ign', [], []))]
# [(0, 1, ('esza', 'esza', 'ign', [], []))]
# [(0, 1, ('mies', 'mies', 'ign', [], []))]
# [(0, 1, ('wypa', 'wypa', 'ign', [], []))]
# [(0, 1, ('wapi', 'wapi', 'ign', [], []))]
# [(0, 1, ('enna', 'enna', 'ign', [], []))]
# [(0, 1, ('pokarbidowe', 'pokarbidowe', 'ign', [], []))]
# [(0, 1, ('pocelulozow', 'pocelulozow', 'ign', [], []))]
# [(0, 1, ('dekarboniza', 'dekarboniza', 'ign', [], []))]
# [(0, 1, ('cyjne', 'cyjne', 'ign', [], []))]
# [(0, 1, ('pokarbi', 'pokarbi', 'ign', [], []))]
# [(0, 1, ('dowe', 'dowe', 'ign', [], []))]
# [(0, 1, ('pogaszalnic', 'pogaszalnic', 'ign', [], []))]
# [(0, 1, ('poneutraliz', 'poneutraliz', 'ign', [], []))]
# [(0, 1, ('acyjne', 'acyjne', 'ign', [], []))]
# [(0, 1, ('poc', 'poc', 'ign', [], []))]
# [(0, 1, ('aln', 'aln', 'ign', [], []))]
# [(0, 1, ('odmia', 'odmia', 'ign', [], []))]
# [(0, 1, ('mgnezowych', 'mgnezowych', 'ign', [], []))]
# [(0, 1, ('einecs', 'einecs', 'ign', [], []))]
# [(0, 1, ('kowalencyjnie', 'kowalencyjnie', 'ign', [], []))]
# [(0, 1, ('poliaddukty', 'poliaddukty', 'ign', [], []))]
# [(0, 1, ('gmdssgoc', 'gmdssgoc', 'ign', [], []))]
# [(0, 1, ('advocaat', 'advocaat', 'ign', [], []))]
# [(0, 1, ('rechtsanwalt', 'rechtsanwalt', 'ign', [], []))]
# [(0, 1, ('advogado', 'advogado', 'ign', [], []))]
# [(0, 1, ('furcraea', 'furcraea', 'ign', [], []))]
# [(0, 1, ('miedzykościelnych', 'miedzykościelnych', 'ign', [], []))]
# [(0, 1, ('miedzynarodowych', 'miedzynarodowych', 'ign', [], []))]
# [(0, 1, ('wiadają', 'wiadają', 'ign', [], []))]
# [(0, 1, ('wyco', 'wyco', 'ign', [], []))]
# [(0, 1, ('faniu', 'faniu', 'ign', [], []))]
# [(0, 1, ('dzającym', 'dzającym', 'ign', [], []))]
# [(0, 1, ('viia', 'viia', 'ign', [], []))]
# [(0, 1, ('sygnalitycz', 'sygnalitycz', 'ign', [], []))]
# [(0, 1, ('fun', 'fun', 'ign', [], []))]
# [(0, 1, ('kcjonariusza', 'kcjonariusza', 'ign', [], []))]
# [(0, 1, ('fotokopiowanie', 'fotokopiowanie', 'ign', [], []))]
# [(0, 1, ('świadczeniowy', 'świadczeniowy', 'ign', [], []))]
# [(0, 1, ('reglaminów', 'reglaminów', 'ign', [], []))]
# [(0, 1, ('kickboxingu', 'kickboxingu', 'ign', [], []))]
# [(0, 1, ('cfe', 'cfe', 'ign', [], []))]
# [(0, 1, ('egz', 'egz', 'ign', [], []))]
# [(0, 1, ('stwie', 'stwie', 'ign', [], []))]
# [(0, 1, ('wwym', 'wwym', 'ign', [], []))]
# [(0, 1, ('kiem', 'kiem', 'ign', [], []))]
# [(0, 1, ('ukoń', 'ukoń', 'ign', [], []))]
# [(0, 1, ('przyz', 'przyz', 'ign', [], []))]
# [(0, 1, ('nanie', 'nanie', 'ign', [], []))]
# [(0, 1, ('kowskiego', 'kowskiego', 'ign', [], []))]
# [(0, 1, ('rzone', 'rzone', 'ign', [], []))]
# [(0, 1, ('teologiczopastoralnego', 'teologiczopastoralnego', 'ign', [], []))]
# [(0, 1, ('szaświadczenie', 'szaświadczenie', 'ign', [], []))]
# [(0, 1, ('prcowników', 'prcowników', 'ign', [], []))]
# [(0, 1, ('niewystarcza', 'niewystarcza', 'ign', [], []))]
# [(0, 1, ('iviii', 'iviii', 'ign', [], []))]
# [(0, 1, ('nowouchwalonych', 'nowouchwalonych', 'ign', [], []))]
# [(0, 1, ('miesięca', 'miesięca', 'ign', [], []))]
# [(0, 1, ('kyrgyskiej', 'kyrgyskiej', 'ign', [], []))]
# [(0, 1, ('rzeczypospo', 'rzeczypospo', 'ign', [], []))]
# [(0, 1, ('spaństwem', 'spaństwem', 'ign', [], []))]
# [(0, 1, ('czeństwa', 'czeństwa', 'ign', [], []))]
# [(0, 1, ('współpra', 'współpra', 'ign', [], []))]
# [(0, 1, ('cującym', 'cującym', 'ign', [], []))]
# [(0, 1, ('torium', 'torium', 'ign', [], []))]
# [(0, 1, ('trifenyli', 'trifenyli', 'ign', [], []))]
# [(0, 1, ('remediacjach', 'remediacjach', 'ign', [], []))]
# [(0, 1, ('współspalane', 'współspalane', 'ign', [], []))]
# [(0, 1, ('próbobierni', 'próbobierni', 'ign', [], []))]
# [(0, 1, ('odpowiadją', 'odpowiadją', 'ign', [], []))]
# [(0, 1, ('remediacją', 'remediacją', 'ign', [], []))]
# [(0, 1, ('brzminie', 'brzminie', 'ign', [], []))]
# [(0, 1, ('helgoland', 'helgoland', 'ign', [], []))]
# [(0, 1, ('buesingen', 'buesingen', 'ign', [], []))]
# [(0, 1, ('livigno', 'livigno', 'ign', [], []))]
# [(0, 1, ('campione', 'campione', 'ign', [], []))]
# [(0, 1, ('ceutę', 'ceutę', 'ign', [], []))]
# [(0, 1, ('melillę', 'melillę', 'ign', [], []))]
# [(0, 1, ('jungholz', 'jungholz', 'ign', [], []))]
# [(0, 1, ('mittelberg', 'mittelberg', 'ign', [], []))]
# [(0, 1, ('kleines', 'kleines', 'ign', [], []))]
# [(0, 1, ('walsertal', 'walsertal', 'ign', [], []))]
# [(0, 1, ('akrotiri', 'akrotiri', 'ign', [], []))]
# [(0, 1, ('dhekelia', 'dhekelia', 'ign', [], []))]
# [(0, 1, ('elo', 'elo', 'ign', [], []))]
# [(0, 1, ('nieprzekraczajacej', 'nieprzekraczajacej', 'ign', [], []))]
# [(0, 1, ('współczynnikowo', 'współczynnikowo', 'ign', [], []))]
# [(0, 1, ('drobnokrojony', 'drobnokrojony', 'ign', [], []))]
# [(0, 1, ('brykietki', 'brykietki', 'ign', [], []))]
# [(0, 1, ('alkilobenzeny', 'alkilobenzeny', 'ign', [], []))]
# [(0, 1, ('alkilonaftaleny', 'alkilonaftaleny', 'ign', [], []))]
# [(0, 1, ('oksylen', 'oksylen', 'ign', [], []))]
# [(0, 1, ('mksylen', 'mksylen', 'ign', [], []))]
# [(0, 1, ('pksylen', 'pksylen', 'ign', [], []))]
# [(0, 1, ('fizycznychi', 'fizycznychi', 'ign', [], []))]
# [(0, 1, ('ustaworaz', 'ustaworaz', 'ign', [], []))]
# [(0, 1, ('wykonywnia', 'wykonywnia', 'ign', [], []))]
# [(0, 1, ('przprzypadku', 'przprzypadku', 'ign', [], []))]
# [(0, 1, ('szero', 'szero', 'ign', [], []))]

# %%
len(not_known_words)
# Out:
# 2541

# %% [markdown]
# ### TASK 8 -- 30 words w/ highest rank not belonging to dictionary

# %%
limit = 30
not_known_occurences = set()
for item in g_freq_arr2_filtered:
    for token in not_known_words:
        if token == item[0]:
            not_known_occurences.add(item)
            break

# %%
highest_rank_not_known_srt = print_frequency_sorted(dict(not_known_occurences))

# %%
not_known30 = highest_rank_not_known_srt[:limit]
not_known30

# %% [markdown]
# ### TASK 9 --- 30 random words w/ 5 occurences not belonging to dict

# %%
import random as r

def find_5_occur(item):
    return item[1] == 5

not_known_5_occ = list(filter(find_5_occur, not_known_occurences))
r.choices(not_known_5_occ, k=limit)
# Out:
# [('państwamistronami', 5),
#  ('agave', 5),
#  ('kpwig', 5),
#  ('tzn', 5),
#  ('ppkt', 5),
#  ('ami', 5),
#  ('regazyfikacyjnego', 5),
#  ('urt', 5),
#  ('regazyfikacyjnego', 5),
#  ('inci', 5),
#  ('agave', 5),
#  ('glinowo', 5),
#  ('odgazowywacze', 5),
#  ('państwamistronami', 5),
#  ('betezda', 5),
#  ('ośc', 5),
#  ('winopochodne', 5),
#  ('najmnie', 5),
#  ('vista', 5),
#  ('denitracyjne', 5),
#  ('odgazowywacze', 5),
#  ('tzn', 5),
#  ('tów', 5),
#  ('swine', 5),
#  ('glinowo', 5),
#  ('rr', 5),
#  ('instrumen', 5),
#  ('swine', 5),
#  ('instrumen', 5),
#  ('państwamistronami', 5)]

# %% [markdown]
# ### TASK 10 --- Levenshtein distance custom (from [norvig-spell-correct](https://norvig.com/spell-correct.html) )

# %%
not_known_5_occ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/x2/kxdjfp3n0vj70bn6f_db0f6c0000gn/T/ipykernel_33403/2879055824.py in <module>
# ----> 1 not_known_5_occ
#
# NameError: name 'not_known_5_occ' is not defined

# %%
# create possible set of words 1 edit away:
def one_edit(word):
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return [w for w in set(deletes + transposes + replaces + inserts) if w in zip(*g_freq_arr2_filtered)[0]]

def two_edits(word): 
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

def get_probability_of_word(words):
    # zwraca posortowne probabilities dla wszystkich zmian w słowie 
    g_freq_arr2_filtered
    
    pass

# %%
wlimit = 10
for token in not_known30:
    possible_replacements = one_edit(token)
print(get_probability_of_word(possible_replacements)[:wlimit])

# %%
wlimit = 10
for token in not_known_5_occ:
    possible_replacements5 = one_edit(token)
print(get_probability_of_word(possible_replacements5)[:wlimit])

# %% [markdown]
# ### TASK 11 --- fuzzy search in ES

# %%
from elasticsearch import Elasticsearch, helpers
#from elasticsearch import Elasticsearch
def insert_sgjp_to_es(filename: str): #-> #Generator[Dict[str, str], None, None]:
    with open(filename, encoding="UTF-8") as file:
        # skip header and license, later proper rows have 4 elements divided with tabs, where 1st is the word
        for line in file:
            if len(line.split()) != 4:
                continue
            else:
                yield {
                    "_index": "dict_jp",
                    "word": line.split()[0],
                }
                break
        
        i = 0
        for line in file:
            yield {
                "_index": "dict_jp",
                "word": line.split()[0],
            }
            
            i += 1
            if i % 100000 == 0:
                print(i)

filename = "sgjp.tab"
es = Elasticsearch()

helpers.bulk(es, insert_sgjp_to_es("sgjp-20211121.tab"), chunk_size=100000, request_timeout=6000)

# %% [markdown]
# ### Fuzzy search  top 30 słów

# %%
highest_rank_not_known_srt30 = [ ('poz', 45224),('późn', 1065), ('str', 516), ('gmo', 298),('sww', 216),('skw', 196),('zm', 192),
 ('ex', 167),('ike', 162), ('remediacji', 120), ('ure', 103), ('rozdz', 102), ('uke', 97), ('itp', 96),
 ('kn', 95), ('np', 85), ('cn', 83), ('pkwiu', 81), ('udt', 77), ('bswsg', 70), ('bswp', 66),
 ('biobójczych', 63), ('phs', 53), ('fep', 42), ('mgo', 41), ('utk', 40), ('frd', 36), ('uokik', 35),
 ('ron', 35), ('cbśp', 34) ]

# %%
#import json
def search_req_dct(word):
    return {
      "query": {
        "fuzzy": {
          "word": {
            "value": word,
            "fuzziness": "AUTO",
            "max_expansions": 50,
            "prefix_length": 0,
            "transpositions": True,
            "rewrite": "constant_score"
          }
        }
      }
    }


responses = []
for word in highest_rank_not_known_srt30:
    responses.append(es.search(index="dict_jp", body=search_req_dct(word[0])))

# %% [markdown]
# ### Fuzzy search top5 wybranych losowo słów

# %%
## TODO
#There is a problem with line endings. Can scan lines looking if
